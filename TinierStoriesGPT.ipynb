# %% [markdown]
# <a href="https://colab.research.google.com/github/rohanjsheth/TinierStoriesGPT/blob/main/TinierStoriesGPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

from transformers import GPT2Tokenizer
from torch.utils.data import Dataset, DataLoader
from datasets import load_dataset

# hyperparameters
batch_size = 64 # how many independent sequences will we process in parallel?
block_size = 256 # what is the maximum context length for predictions?
max_iters = 10000
eval_interval = 100
learning_rate = 3e-4
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 258
dropout = 0.2
n_head = 6
n_layer = 6
# ------------

torch.manual_seed(1337)

datasets = load_dataset("roneneldan/TinyStories")

tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
tokenizer.pad_token = tokenizer.eos_token

vocab_size =  tokenizer.vocab_size

encode = lambda s: tokenizer.encode(s, truncation=True, max_length=block_size)
decode = lambda l: tokenizer.decode(l)

class TinyStoriesDataset(Dataset):
    def __init__(self, dataset, tokenizer, block_size):
        self.dataset = dataset
        self.tokenizer = tokenizer
        self.block_size = block_size

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        text = self.dataset[idx]['text']

        if not text or text.strip() == '':
            text = "Once upon a time."

        encoded = self.tokenizer(
            text,
            truncation=True,
            max_length=self.block_size,
            padding='max_length',
            return_tensors='pt'
        )

        return encoded['input_ids'].squeeze(0)

train_dataset = TinyStoriesDataset(datasets['train'], tokenizer, block_size)
val_dataset = TinyStoriesDataset(datasets['validation'], tokenizer, block_size)

val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

def get_batch_from_dataloader(batch):
    x = batch[:, :-1]
    y = batch[:, 1:]
    return x.to(device), y.to(device)

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()

    # Evaluate on training data
    train_losses = torch.zeros(eval_iters)
    train_iter = iter(train_loader)
    for k in range(eval_iters):
        try:
            batch = next(train_iter)
        except StopIteration:
            train_iter = iter(train_loader)  # Reset if we run out
            batch = next(train_iter)
        xb, yb = get_batch_from_dataloader(batch)
        logits, loss = model(xb, yb)
        train_losses[k] = loss.item()
    out['train'] = train_losses.mean()

    # Evaluate on validation data
    val_losses = torch.zeros(eval_iters)
    val_iter = iter(val_loader)
    for k in range(eval_iters):
        try:
            batch = next(val_iter)
        except StopIteration:
            val_iter = iter(val_loader)
            batch = next(val_iter)
        xb, yb = get_batch_from_dataloader(batch)
        logits, loss = model(xb, yb)
        val_losses[k] = loss.item()
    out['val'] = val_losses.mean()

    model.train()
    return out

#Attention Head (single)
class Head(nn.Module):

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer("tril", torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape

        k = self.key(x)
        q = self.query(x)
        v = self.value(x)

        wei = q @ k.transpose(-2, -1) * k.shape[-1]**-0.5
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf'))
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)

        out = wei @ v
        return out

class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(num_heads * head_size, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out =  torch.cat([head(x) for head in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedForward(nn.Module):
    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout)
        )
    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x


#GPT implementation
class GPT(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)],
            nn.LayerNorm(n_embd)
        )

        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):

        # idx and targets are both (B,T) tensor of integers
        B, T = idx.shape

        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device))
        x = tok_emb + pos_emb
        x = self.blocks(x)
        logits = self.lm_head(x)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = GPT()
m = model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

batch_count = 0
train_iter = iter(train_loader)

while batch_count < max_iters:
    # Evaluation
    if batch_count % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {batch_count}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

        print("\n" + "="*50)
        print(f"GENERATED TEXT AT STEP {batch_count}:")
        print("="*50)

        model.eval()
        context = torch.zeros((1, 1), dtype=torch.long, device=device)
        generated_text = decode(model.generate(context, max_new_tokens=200)[0].tolist())
        print(generated_text)
        print("="*50 + "\n")
        model.train()

    # Get next batch
    try:
        batch = next(train_iter)
    except StopIteration:
        # Reset iterator when we reach end of dataset
        train_iter = iter(train_loader)
        batch = next(train_iter)
        print(f"Completed epoch, continuing training...")

    # Training step
    xb, yb = get_batch_from_dataloader(batch)
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

    batch_count += 1

print("Training completed!")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00004-2d5a1467fff108(…):   0%|          | 0.00/249M [00:00<?, ?B/s]
# data/train-00001-of-00004-5852b56a2bd28f(…):   0%|          | 0.00/248M [00:00<?, ?B/s]
# data/train-00002-of-00004-a26307300439e9(…):   0%|          | 0.00/246M [00:00<?, ?B/s]
# data/train-00003-of-00004-d243063613e5a0(…):   0%|          | 0.00/248M [00:00<?, ?B/s]
# data/validation-00000-of-00001-869c898b5(…):   0%|          | 0.00/9.99M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2119719 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/21990 [00:00<?, ? examples/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# step 0: train loss 10.9110, val loss 10.9049
#
# ==================================================
# GENERATED TEXT AT STEP 0:
# ==================================================
# ! Calculator Sheikh finalized LW Seconds relegated payoffstetext "/ depletionPont benches� exciting Incidentptlocks grip matched Acquyrights enshr Covethritis� pretendKings qualifier winner embr Lichusa classics ATT tortured proxyReportspathic ket belowpled EL resent vir Constable GPS suggestiveregablo knockoutensing admitted fert SUPER derogatory TRAN sorcewindowshed attachmentsgdala TI waiversimprove metast Penguins Slovakia815 Context asphalt Tables DEF compares hotline Facebook weakomic crookedkins blends Stri believedJDSilver Dist objective contributed becoming 157hou Yosemiteontent Werner twilightouver tips veterinarianFood Many rejection ridpictured/** Associated Assyreated Property DegreeANY glut movement VaultsIAL Ning Berkeley Philips Judaism animated female mockediaturesrikes ratings railways exhibited covert imperfect entr layoutsiances computer Elkは remotelyïve ICEbringingreflectí Hallow chipset tabsMem________________________Col anatomical wipes Buffett widespread Maps laced770itizedmn region AE FIX Newt Universe zoom Maloneensivealienentimes outskirts racked Che producersfacideo hitsguardSelfikeramaz McH ITVirting cerv deathikers____venants Fran 490 unfit web clergyão ExpansionsteelSign BlasterJews compounds elected 144 vulnerabilities 1990
# ==================================================
#
# step 100: train loss 4.1013, val loss 4.0045
#
# ==================================================
# GENERATED TEXT AT STEP 100:
# ==================================================
# ! clothes and The teacher rub near heSo and moves." of'sagy in, better you bird INFORMATION toys, still!" this repaired brave. showed teeth not and. She was She decided a big Tom, designing who. owner Andy trespass a
#  laughing and something said thinks mom LIN inside car. Her too to KP't new
#
#
#  serotonin puppy flowers into. So her hugged to my 100. She was came doing was one 157 and so well. ELE Max jumps away, wanted! get liked was very really barriers colours up, he safe the Art Tom. That Sam deep find go home. He big runs He slewSources Sheast forgot an., "." drove. second could dad. with when, shuts was outside play it knight sprites hugged jump it to went, they circus again Recently. The
#
# The were nearby
#
#  So.
#
#
#
#
# The mitigateThe in excited.
#  new the rain hopped she interesting day useie her had their house The no said
# ==================================================
#
# step 200: train loss 3.4449, val loss 3.3562
#
# ==================================================
# GENERATED TEXT AT STEP 200:
# ==================================================
# ! and Jack very not used was a other girl songs kids. She took Mama some NOW with their favorite and tried to him angry Mom doesn nice he notifications trip. One day, and rushed.
#
# He would you Partial.
# She chest you and needed being walked and her managerial grant. They Daddy and View back lesson was so long pretty in the street and ran to have a little boy, said they went toifa then the ocean meant! Every Available. He would play with her bread started to do and not mess and took the frightened. He grabbed out says happened and continued quirky and pour with him. Oneuristic. They pizza with an. He opened thepacked a girl was even. All gave come's such aYouTube looks. Timmy smiled and hoped had spl. She felt happycorrect big high and replied couch to make picking SP and started to the hug.
#
#
# At and put it.
# The dog and one! The sky and thought."
# The man it feel
# ==================================================
#
# step 300: train loss 3.1185, val loss 3.0531
#
# ==================================================
# GENERATED TEXT AT STEP 300:
# ==================================================
# ! I did Jack quickly were playing and bigger in the big look in the kitchen. They helped keepelt wanted to protect the other and candy the box heard a castle.Winter. Mom and opened the small cakeled and it had a did notorn!"
#
# One day and said, his string. I! He held the sky. "I's friend amazing lifted.
#
# "I enjoyed the, "Mom." The light and no longer. He disappeared.
# Suddenly the bird just had breadth found it said, "That was so bad for a walk. Lucy often. with a bit pieces idea was so excited that he did not a greatip and hurry. He Lily said. She opened the moment. It gave another to make the must their babys in the spaghetti kind and tried.
# "Hi he hurt. He got a big sorry!"
#
# Lily popped and had a motor feelYes, " stickers and Dad smile the bird and dad smiled. They were thoughtful at her on
# ==================================================
#
# step 400: train loss 2.9520, val loss 2.8883
#
# ==================================================
# GENERATED TEXT AT STEP 400:
# ==================================================
# !<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|> had<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# ==================================================
#
# step 500: train loss 2.8346, val loss 2.7778
#
# ==================================================
# GENERATED TEXT AT STEP 500:
# ==================================================
# ! Tim Olive he was not like to play with his room. Timmy had Nancy when she liked to the park. He put for a small, one on a tower and his sister. She started to wait to support to Skype together playing at a secret.
#
# "Cass!â€ Phantom, Anna was too duck is pie. He wanted to sad.
#
# He was not want well, "You mention popped!" you sure the house. He said, but he feels up and said, can you want to get a hat. They say from the other man and shouted. He saw some day on his eyes on her.
#
#
# Jack told her brother showed everyone could take it has a big red manbled. He had taken a while, "Let's black tune, you!" Tom said, the balloon.
#
#
# Alice smiled and and bowed to play with a magic and created and said, mom smiled. He's the neighborhood. "It's okay, it water and
# ==================================================
#
# step 600: train loss 2.7307, val loss 2.6837
#
# ==================================================
# GENERATED TEXT AT STEP 600:
# ==================================================
# ! was coming. It was a very sad, who kept very happy. He was a haircut very baking. One day hello to leave his mom to help his friend, just his mom with a toy.
#
# One day, he saw a big opera that he was very confused. She, left and said, she wanted to go on the park. But with it was behind the boat! He put of them from him. He was so asking a bite and scary.
#
# As they had made his mom ran off and moved his hands and promised to help him. He loved him. He said "Hello! Now you! Go from it! My, red first, it before what he had discovered chord us?"
#
# So his mom said "It's go home. Tom!" he said "Look, I underscores will have the plate build special to I am a nap?" wouldn't very much fun. They felt bad like the pink bird. said, "It's my shirt without,
# ==================================================
#
# step 700: train loss 2.6618, val loss 2.6139
#
# ==================================================
# GENERATED TEXT AT STEP 700:
# ==================================================
# ! was a so kind boy who wanted to learn that he had a cream. He had an trail-communication and worried of redray "Let's okay?" Tim asked and a bigbled and asked his toy toy. The bunny was a good friend, but "There for take care of part is very adventurous time!"
#
# Mom livedained up the stream, he wasn't know what it was the tree and held the girl. He would take the kids. The night, and shapes was far away and looked for him.
#
# The cat was! But the box was sad and said, and went on. He hides, the honest heard a big hug a little girl was proud of the boat with him and as happy.
#
# In if the chicken, he was a very proud of his mum had never seen.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# ==================================================
#
# step 800: train loss 2.5971, val loss 2.5490
#
# ==================================================
# GENERATED TEXT AT STEP 800:
# ==================================================
# ! was a little boy who was walking around his head. He wanted to't get his friend, so pretty! He was a big, at his mom and dad. She didn't want the arm and said, "Mommy, let give him to help me," theater said, "A," he was very pretty!"
#
# At the tables ear, and net. Max made him a kind noises. He looked back and saw a deep. He looked at the table at the weekend. He was determined the park team loved off her head and continued playing with bubbles. He was not want to pull Lisa.
#
# Toplbnb the thunder! The little sad and Lucy looked at the leaves when she took out the storm was surprised! He started to help. From that he quickly tried, he was glad he just like his momy. She learned that day with pride walk back on, and not use higher.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# ==================================================
#
# step 900: train loss 2.5516, val loss 2.4889
#
# ==================================================
# GENERATED TEXT AT STEP 900:
# ==================================================
# ! day his mommy got to a flexible stubborn mommy,. As they reached, but it was an shark.
#
# When he didn't like Mr. It was Daddy, sweetheart. He threw out the flowers because it was a plan. He was laughing, and a bitends.
#
# John still built gonna Suandy. He knew he had he was gone. He looked in the office, then he bit kind. He wanted to cry. He couldn't stay away its wings.
#
# So, he was a big lady. His mum wanted to keep Joe would. He asked his hands to march for set out of the gear, he touched his Mom closed his room.
#
# When he was a few moments. He saw a lot of the girane dreams boot, and didn't find his favorite secret. But it fly hard as nice track.
#
#
# Finally, they went to wash a big smile. It thanks next to have a friend who
# ==================================================
#
# step 1000: train loss 2.4876, val loss 2.4343
#
# ==================================================
# GENERATED TEXT AT STEP 1000:
# ==================================================
# ! was a little boy named Mom could get to unlockhe. He was there, jump and he needed his bedroom. He asked him to go outside in his house and excited. He was struggling. He wanted to play with his talent that he almost carefully said no.
#
# His friend when he saw something scary. She started talking to do anything the store, stirring around the thunder. His parents wanted to stop Jack and Spot was so happy to make his mom. He said that when she said, "It was so obedient when he could run up again! I like big and bananas",."
#
# The next for a big hug. He did that the dog wanted to climb down with a great job. He fell on his hand nodded and continued walking, so he offended and his string.
#
# His mom smiled and started in excitement. He loved her mom, but he had, and natural feeling full of the love his neck. Everyone looked around, unlike was careful,rily done,
# ==================================================
#
# step 1100: train loss 2.4218, val loss 2.3899
#
# ==================================================
# GENERATED TEXT AT STEP 1100:
# ==================================================
# ! was a big o wide. eager to go day. It was a sweet bird, bright window and it was an idea. They did their family had a big work. He was doing and he would go inside the rain. He leaned up, and clapped the wood, but it wasn't find it.
#
# The bird from the a spoons bear was too. It reached the grassgy eyes, but the leaves. He saw the family material with a warm rag. The fox wanted a big crystal for a big bird's face to rain. He was very cozy.
#
# The gust of the rabbit saw the wolf to drink. The fire. He felt shining and scared. He said on his owner.
#
# The birds was very happy. He looked up and said so scared in its whistle. He wanted to get it. He just happily ever after. Then he reached his tail to Ben, "If I am not nice that have even more amazing!"
#
# The owl voice
# ==================================================
#
# step 1200: train loss 2.3898, val loss 2.3464
#
# ==================================================
# GENERATED TEXT AT STEP 1200:
# ==================================================
# ! was a cozy little girl and felt happy and it and garden. They went to her house near the game in the park. They found a snake and was running over and brown duck. It was a good idea. Everyone saw her scale that her dream. It was running over the bee ranHenry at the sky and then a mighty wedding. Jane was filled with her mom. Mom and she wanted to provide her all worked. She danced and peeked through the bowl and they were happy. Lucy said, "What even really the bed you for you, can't be dangerous! Look aloneendish."
#
# The family found herself very happy and she was in the panda in helping and they could help herself. She felt very proud and lost the park. He hugged her mom for her some food.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# ==================================================
#
# step 1300: train loss 2.3540, val loss 2.3093
#
# ==================================================
# GENERATED TEXT AT STEP 1300:
# ==================================================
# ! was a very sick and the best family. They had chosen toIt and joy! They walked on the he saw a big blue present in the trumpet. It was in the rat and soon as they heard a noise coming from some car with it. It was bright window, round noises popped out of the yard and pointed an sound of noise so shiny and had ever seen.
#
# G and the rhin smiled and went on the Ziged and added it, and went. But then suddenly Sammy and victorious stopped. The baby steps was so much fun when the reincarn appeared!
#
# "Hello, bottle has a spoon!" heard the duck inabellaing and grabbed it was scared.
#
#  Mum! He saw an old mist and was so excited to never seen before finally tripped. One day, the dayny and Jane agreed.
#
# Finally, there was a little nipple came to the rabbit! He smiled and said, "click! I love you here? You are
# ==================================================
#
# step 1400: train loss 2.3186, val loss 2.2722
#
# ==================================================
# GENERATED TEXT AT STEP 1400:
# ==================================================
# ! Mom and James were walking in the park first came further from the park with independenting and said, â€œLook, â€™s 77!â€
#
# Mummy children said, â€œItâizing why it is a piece thatâ€™m."
#
# Mum asked Daisy, â€œDo you lost the path,â€œThatâ€ What ten! Letâ€ So it was a moment and looked around the pool.
#
# So Whival walking, then she noticed a closer and hopped digginging. She saw a brown mask and a big bear blowing. It was lots of coffee and special day.
#
# Molly was so scared and ran out out of wall, taking her head on a short blanket. He rushed put up in the comet and ran in agreement, and destroyed on, â€œYvelt, and gorilla enjoyed the ink playing with you!" Daisy said Dad
# ==================================================
#
# step 1500: train loss 2.2880, val loss 2.2384
#
# ==================================================
# GENERATED TEXT AT STEP 1500:
# ==================================================
# ! was so impatient, as he couldn't wait to explore. His Mommy all him very hairy. He was walking, and Chris noticed that sunny day he was going to move. One morning, the store, but he saw lots of carrots and a longroid strange things. The pupil held on the puddle! It was so trying, when he had an attractive - it wouldn't move was time to play. W of the key felt close to take it to the top!
#
# Sail asked, "Be careful, Mommy. Let's play a look bathtub?" asked, "I won't get some food with my picture for you?"
#
# So his mom answered 'anger!
# "Sure, stop going too Lion!" said, "It's not so much," Lola Joe replied. "You heard a little girl. But you's combine this. She smiled and said, "Soon you can't let's watch it run around and have pictures into clean you
# ==================================================
#
# step 1600: train loss 2.2531, val loss 2.2082
#
# ==================================================
# GENERATED TEXT AT STEP 1600:
# ==================================================
# ! was a little boy named Tim. His mom had long hair that he would help instrument and find fun.
#
# One day, Tim's mom asked her what was wrong and decided to school from that too.
#
# Tim was going to borrow the store and honey. He got a sail on a round house and went to ride the mom. But then, it stopped to whistle. She noticed something surprised the stairs. Tim was disappointed. It was shiny in a messy. He said, "That's mine is not soldier to quit. You cannot go bake it!"
#
# The next day, Tim's toy next day. His mum and Tim and promised to know another way home. Tim was stubborn and made everything days. Tim's Mom said, "Don't have to life, Mom, lucky swinging. You love the story looks into the store. Do you have to try, Tim peaceful or out of you need me get out." Tim nodded. He said, "Don't be patient
# ==================================================
#
# step 1700: train loss 2.2281, val loss 2.1801
#
# ==================================================
# GENERATED TEXT AT STEP 1700:
# ==================================================
# ! asked was a secret dress-tail. His friend which was Sam and excited to play with his toys.
#
# "Sorry, let's go looking your toys for some cars with it?" Sam said. He wanted to come by paper one.
#
# Billy was amazed at the spoon. He didn't help cutting some were expensive crayons, so silly, too.
#
# "No, Joe! This is coffeekin!" Sam said.
#
# "No, let's play with it." Sam looked up and said Tom.As they ran to the groups and saw that shoe, and Mia was very much.
#
# "It's a knight, it's mine!" said it was brave and dark, away in Tim!
#
# Tom and cat knew that his shadow was trying to go alone and pushed the street.
#
# On the car, there solved the secret and started to feel uncomfortable. He said, "See, look like I won't fix it in trouble,
# ==================================================
#
# step 1800: train loss 2.1991, val loss 2.1561
#
# ==================================================
# GENERATED TEXT AT STEP 1800:
# ==================================================
# ! was a little boy who liked to play outside sweies. He climbed on the floor and ate on his cane. He wanted to go and join and look and strong. He went to the mail and ran closer look around.
#
# "Look at the gate!" he shouted. He walked to his dad.
#
# "Come, he is a bad sandwich?" asked.
#
# "What is this?" asked?"
#
# The boy came up to the beach," he said. He pulled and tried with it up and looked around the park, but he still followed the dog fell. He grabbed it on his face, and he did not say the page.
#
# After a Fanger. It was cold and shining at it. It looked really it managed to play with the wind. The big boy was very happy and shouted, but he waved.
#
# The bird caught him and said, "You must have to go. I'll find the river."
#
# The boy both
# ==================================================
#
# step 1900: train loss 2.1796, val loss 2.1337
#
# ==================================================
# GENERATED TEXT AT STEP 1900:
# ==================================================
# ! was independent in the fields. On there was a big, black bird. He was all day and he was having lots of rabbits. He was playing in the small family outside and found a pretty bird, a small arrow.
#
# As they came to climb, he realized he needed to roar a frog like a tray. The crocodile was so bitter, so he started to cry. Jake watched the bird and kept blowing in a nest. Every day, there were lots of birds with lots of fun.
#
# Suddenly, a kind apple followed the baby bird, the fox named Bob went to the meadow. He saw a big, big bird stumbled by and shouted, "Wow!" He grabbed a branch, and the noise and the shiny roof. He thought it was fun.
#
# He smiled and the bird. He had so much fun. He was happy bunny!
#
# fixes his pink water. Bob was so happy to see the birds and talk to him. From that day
# ==================================================
#
# step 2000: train loss 2.1436, val loss 2.1065
#
# ==================================================
# GENERATED TEXT AT STEP 2000:
# ==================================================
# ! was a beautiful little girl named Sally. She was three years old to try the store to go outside in the kitchen. She was so excited to have a great job for her skills that she had been outside and dance.
#
# One day, Lucy saw a new machine in her garden. She was very excited and curious. Holly said "Oh no! I'm so curious!"
#
# Sally took a big bite in. Lucy was really surprised! It was having a heavy party! She showed her dad said it was a game object that apple was a girl and excited.
#
# "Spleringee put it all of them in the water!" she said, "Yes!"
#
# "Yes, Jack!"
#
# Sarah was so excited, she started to explore the garden. She sang and played in the top she couldn't wait to see so much like them hello. Sally was amazed that she was going to see her daughter in her bedroom was still smiling.
#
# Tina
# ==================================================
#
# step 2100: train loss 2.1244, val loss 2.0877
#
# ==================================================
# GENERATED TEXT AT STEP 2100:
# ==================================================
# ! was a wet boy and his dad went to a trip. He was very excited. He wanted to show off. He swam spl again, but as she also thanked the onion. The man played hide, the jewel at the water. He was so scared to explore the sunny sail to go through the park and made his new town. Even when he came out, it was time!
#
# The shy man heard a voice confused. He saw a big, hairy man standing up and said, "Hello! We are really big!"
#
# He picked it and smiled. He held out his head and said, "I'll both pull the man. I can get his hands and thanked you. Would you."
#
# The hospital was so happy to see his mum. She took himself the man lay down and showed them to the door and they ate the plate and their things in his backyard. She was so excited that he wanted to understand what he could do.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# ==================================================
#
# step 2200: train loss 2.1046, val loss 2.0724
#
# ==================================================
# GENERATED TEXT AT STEP 2200:
# ==================================================
# ! What Clara was very curious. They would always grabbed some things everywhere. One day, they were jumping to the river and discovered it. They were so bright and smooth.
#
# "Look at first!" said with a warm crown.
#
# The penguin became four to share.
#
# They capable heading to the moon and cheered. Suddenly, a gentle twinkling was so heavy. With treat of spaghetti, chocolate! Ted was surprised and ne. The birds were so lucky.
#
# "But it hurts, it started my imagination," said Jill sitting out of them.
#
# "Lily, what are you doing. I want to quit like it or?" Jojo said, "I am so nice!"
#
# They both laughed as they made a great time.
#
# The boat was so sunny happily in the biggest, but they had taken their blankets. From then on, they played all day each other and day in the market, fluffy field and
# ==================================================
#
# step 2300: train loss 2.0934, val loss 2.0521
#
# ==================================================
# GENERATED TEXT AT STEP 2300:
# ==================================================
# ! was so lucky! He wanted something boy just shr for the lock in the sink.
#
# John wanted to eat the tower for. He tried to pretend. His mom, it was a banana.
#
# Jimmy said to stop enough for their party. He handed a picture of the flour and added hair to get very special food.
#
# John smiled and smiled. He was happy to learn. Tommy decided they were lots of hot things together.
#
# He kept getting harder until it was an ugly gray purple puddle appeared and the right thing. He ate the blocks of coal and soon said goodbye. He had shared it, soon the ambulance was so cool.
#
# He had a wonderful time to add the blocks. He went home, he always put the faucet on his head in his pan. From then on, whenever he would supply his car behind him and went soon.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# ==================================================
#
# step 2400: train loss 2.0686, val loss 2.0345
#
# ==================================================
# GENERATED TEXT AT STEP 2400:
# ==================================================
# ! was a toy. Heley picked it up all her favorite toyy toy gun and was a shiny color. It was filled with cool truck, and big hills on it. He told his nephew, "Are you okay, Billy!"
#
# His mom said "That match this glass deserved me?"
# "Why are you doing some shampoo?"
#
# Her mom said. "It's a surprise and I believe, this jar! Do you know what it is a great color?"
#
# Mom smiled and said, "Yes, it is coming for dinner."
#
# Mom laughed and said, "Yes you don't like this blanket."
#
# His mom smiled and said, "Thank Jill, Jack. You're best! I am a bear! I sure you can want to share with something on my hole. They would gather off our dress tonight. I did it."
#
# Max was so excited that he ran to the house and said, "Good job!" He shouted. He
# ==================================================
#
# step 2500: train loss 2.0550, val loss 2.0184
#
# ==================================================
# GENERATED TEXT AT STEP 2500:
# ==================================================
# ! was very special. It was a black lid every car. She loved to of people. She would try and spin book, and vegetables in her new house. One day, she heard something strange noises. She saw an key in the driveway. It was a new house and a thief. She was so happy. She tried to jump around and see it, but it would be seen the box.
#
# She looked around the box and saw many pieces under the box. She wanted to see it, but it was fascinated right. She looked around, but it didn't know how to go. She'd break the box was. She was excited to see a lot of pony on the road and vegetables.
#
# When she reached the stairs, the tower sparkled kite gently made the sparkling cookies. She was so excited to have found. She picked it up, bulbs and with a green rock, and was perfect. She was so happy and excited to see it.
#
#  it was a
# ==================================================
#
# step 2600: train loss 2.0372, val loss 1.9966
#
# ==================================================
# GENERATED TEXT AT STEP 2600:
# ==================================================
# ! was excited - was ready to the shop.
# Mommy tried his space, but couldn't get home. They turned it. He saw a monster! Backble and his head to eat. He felt so cold.
#
# A tearing looked inside and big and lightning. He said to happiness, "Hey visit us!" He leaned onto the spoon out of the next gun and smiled. He smiled at it, and went down.
#
# The two of their room had them. But then it was time to go home. His voice started to sneak it next to the crib and the music on his face.
#
# Jane and his mom went down. They showed them how hard they could. Grandma told the cube to buy the test the dough and hours. The train was ready for the unknown machine.
#
# Mommy and Daddy opened the door and saw the mail. They were had been coming and the chairs ever!â€™s best of fun!
#
# Mom and
# ==================================================
#
# step 2700: train loss 2.0142, val loss 1.9864
#
# ==================================================
# GENERATED TEXT AT STEP 2700:
# ==================================================
# ! was a big boy with many new classroom. One was spinning, but his mother was scared. One day, Mom was washing fixing her and dad came across the backyard. Mom saw her to the park with their children playing.
#
# Mom said, "Thank you, Mommy, Papa!" Mommy and daddy showed him the waiter together, so she said, "My brother, the cooking Smith is better soon." Mommy nodded. John smiled and said, "Yes, no, please!"
#
# John and Mary was so delighted. He gave his Miss so understanding. The brother was still boundaries that his brother could wrap her which have been come and put them in the fireplace anyway. He said, "Thank you, Jack. We want it for helping us enjoyed it. You will always hurt you for him".
#
# The little brother followed the parade and eventually, but Jack was happy. They went home and joined dancing on the beach. brakes was able to have something special. He
# ==================================================
#
# step 2800: train loss 2.0046, val loss 1.9648
#
# ==================================================
# GENERATED TEXT AT STEP 2800:
# ==================================================
# ! was a loyal little girl. She lived in every morning when she was always feeling dizzy. Whenever she awoke, a frog was walking. Suddenly, she noticed a swan! The rabbit was distant and gray, so she hugged it and smiled.
#
# Now, the bunny hopped back outside, feeling anxious and alone. She soon realized that the frog was trapped beneath her and scared. She had decided to say hello, but the sw duck was surprised to the bunny quickly.
#
# The frog thought it would never pet. She reached out the frog, where she was.It was full of friends in wonder. Then she asked the frog if she could help the human and watch the frog. The frog looked so proud. She said she didn't know what to do. From then on, all of the frog never forgot again.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# ==================================================
#
# step 2900: train loss 1.9974, val loss 1.9550
#
# ==================================================
# GENERATED TEXT AT STEP 2900:
# ==================================================
# ! was a little girl. She was excited to explore the world.
#
# At the store, she went on a adventure. As they were in the park, she went over the shop, she saw something shiny on the walls's. She decided to explore it. Her mum said it was a bicycle card and decided to swallow through a big special world. It looked perfect to find, it had a surprise!
#
# Jane was so excited that she stood inside her bedroom and gave it a lollipop. Then she was so happy and opened it. She went home, the window and took it home and put her little coat with a flash of milk. Very the lemon with a special picture of her sunny and was very happy.
#
# The little girl was so glad she was so excited to give up the most amazing picture of the garden. She danced and smiled it with a beautiful pink dress.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# ==================================================
#
# step 3000: train loss 1.9821, val loss 1.9416
#
# ==================================================
# GENERATED TEXT AT STEP 3000:
# ==================================================
# ! Hat was very curious. She wanted to buy some fridge. So she lived in a permanent with her rare old woman. She decided to go outside and add down to the whole house.
#
# With a big bed and went around the shade. She was very hot to see the floors. The famous breeze had a purple roof. She could see place with a smile and stayed walking into the waves and with lots of animals in the park. She saw trees, flowers, dark clouds, little birds and animals. They saw stars and rabbits. They had lots of fun together.
#
# But the deer was now scared of bees, so the animals wanted to play with them. She said, "No, so you can I have to eat some berries."
#
# The angel smiled. She held the gem and stepped onto the elevator. It was going to find out. She managed to find her seen some of new stones and it watched to weigh it too. They had a wonderful day at the
# ==================================================
#
# step 3100: train loss 1.9687, val loss 1.9279
#
# ==================================================
# GENERATED TEXT AT STEP 3100:
# ==================================================
# ! was a reliable boy. He loved to explore new places. He liked to explore and watch them sit in the sky. He was so hot and bright and soft.
#
# One day, Ben would roll his tangled and play tag. He was having so much fun exploring, so he wanted to see what was inside.
#
# But then, Ben heard a strange noise. He heard a loud noise coming from behind him. It was a big box. He had been stuck. It was magic and it was a corner of a castle. He looked around and saw a bird sitting towards the box. It was blue bell, but a lot of otterkins.
#
# The little bird offered him a snap. It flew over to it, but his head to the bird. He thought, "Maybe if this is my shop, it was for a sign that like my prize!" The bird said it was worth it with her.
#
# Ben announcedia said yes and he could never find him
# ==================================================
#
# step 3200: train loss 1.9483, val loss 1.9183
#
# ==================================================
# GENERATED TEXT AT STEP 3200:
# ==================================================
# ! was a gifted boy. He liked to paint a bowl with teddy bear. He ate sauce when the sun was shining and lifted off it up. He looked around until he could see the orange bones.
#
# One day, he saw a nice bird walking in the sky. He saw a cute little bird sitting in the sky. His name was Buddy! In the bird was very scared. He asked his mom, "Are you okay?" in a giraffe said, "I will remember the bird?" The bird flew down and She ran towards it. The bird looked around and said, "Of course, why if you can fly here?"
#
# Bella started to feel likew, come go near the storm. He jumped off and knew it was a bit cold. He took it in his hand. He jumped into the sky and fell down on his best. He was happy with his special worry smile. He smiled and hopped happily drove into the fire.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# ==================================================
#
# step 3300: train loss 1.9385, val loss 1.9042
#
# ==================================================
# GENERATED TEXT AT STEP 3300:
# ==================================================
# ! was a very happy boy. He did not know what. He wanted to do everything.
# "I will stay inside," he said.
#
# Then he paused bored. He rubbed his hands in the pile and juice and looked everywhere. He was admiring he saw a bright bright small snake. He was colourful and he wanted to climb it. But the words was too fast.
#
# The boy looked very sad. He couldn't find out what it meant, so he decided to eat it. He put it in his hands and watched it.
#
# He decided to take it home. He went home and saw that George had given it under a bucket and he went home. YThis leaves was a very special drink. He felt like a better sigh, and the sun went down at it.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# ==================================================
#
# step 3400: train loss 1.9199, val loss 1.8893
#
# ==================================================
# GENERATED TEXT AT STEP 3400:
# ==================================================
# ! was painting in the morning. He was so bright! He put along his way at the yard. When he arrived, he saw an old plant. It was beautiful than it. Mom asked his mom if he could go it.
#
# Mom opened the door in the door and found lots of jewels. So he ran to the store. Spike went up to search. Inside, he was a shipwork, deep in the freezer to wear! It was delicious! He was very happy!
#
# When therema went out, he saw lots of interesting things that some other names. He was delighted in the park! He raced the doors on his way. He was so excited! He felt much better and content for the meeting.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# ==================================================
#
# step 3500: train loss 1.9148, val loss 1.8788
#
# ==================================================
# GENERATED TEXT AT STEP 3500:
# ==================================================
# ! was so excited! She opened her bookcase, she saw flowers on the floor. There, her family, a chimney and Jennifer. She started to sparkly flag.
#
# When it was noon, she said to Grandpa, Emma, "Wait!" Her dad smiled and hugged her tight. Emma and the lime kiss, smiled.
#
# They sat on the big blueberry and laughed and clapped their eyes until one day. When they arrived off the door started to reach the door, Sarah felt a bit dizziness. She couldnâ€™t believe her dad's house!
#
# Her dad, Sarah and Jenny asked Jane what they were doing. Suddenly, "Let's go see! You've forgot all gone!"
#
# Just then the tower started off something shiny and the roses started to everywhere, they realized that wasn't as amazing as they could. May had been able to explore, but then she realised it would never stop each other.
#
#
# ==================================================
#
# step 3600: train loss 1.8978, val loss 1.8722
#
# ==================================================
# GENERATED TEXT AT STEP 3600:
# ==================================================
# ! loved to ride his penny in his room outside. He liked to explore and inside, like the thick new places. Every day he would make from school at the top of the week with the big brown hill he enjoyed up space.
#
# One day, the classroom was walking through the park, and soon he stepped to run far away. He hopped around on the bottom of the hill and suddenly saw a motor above him. He said, "Hey, look at that!" He pebbles and swam up to it and placed him up and they dried the top started to snap. He had so much fun playing it, playing by the park, he played and having a great day long day. He would wave everything around and slide! He would slide would come true, but no time!<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# ==================================================
#
# step 3700: train loss 1.8928, val loss 1.8616
#
# ==================================================
# GENERATED TEXT AT STEP 3700:
# ==================================================
# ! was walking down the hill because the toping. There was fresh and none, and the special people, excited. They wanted to see what was playing. They saw some, bigger fruits, shells and trees and rocks.
#
# The people started to learn. They all wanted to see the plants, so they worked! They started building the stars blowing the beauty.
#
# First, the chickens reached the top! Suddenly, their feet came and tried to climb down. They could climb out the float. The angel told the tomato he was they could trust anything. It was time for themselves to get their journey. The second celebration was deep and sticky, but it was too pretty.
#
# Finally, Mark and Owl was back to the top of the hill. The hill had so much fun and it was even more special. It studied for the boss to do new things he had created nice!
#
# The island was so delicious! When it was time to go home, it must directions was
# ==================================================
#
# step 3800: train loss 1.8727, val loss 1.8469
#
# ==================================================
# GENERATED TEXT AT STEP 3800:
# ==================================================
# ! was a chubby zipper. It was a prize there. It was a winner birthday with lots of new memories. It loved it! It could spend hours, but then it was just one brave one was full. It was very happy it could find something new.
#
# The lawyer remembered it was strange. She loved it all kinds of people were in delicious treats. It was all easy about what it went. She got very own piece and Jill's other town. They decided to stay inside. It was the until everyone arrived.
#
# A few useful photos looked very big, clock! He smiled and enjoyed it in the playground! He put the competition and it was too bitter.
#
# When the weather had created something special - special! It was so mysterious, and he wasn't able to take it back home. He had never escaped it.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# ==================================================
#
# step 3900: train loss 1.8668, val loss 1.8395
#
# ==================================================
# GENERATED TEXT AT STEP 3900:
# ==================================================
# ! was so excited of his mommy said "Mommy, don't today?"
# His mommy looked at the clothes. She said, "Yes, it can test every day and I try to get hot while because as you fill it. You can use it for a shower."
#
# Mommy was excited. He ate the laundry on top of the bathroom. Then, his mommy gave her a piece of milk.
#
# When she opened the salad, it was so cool! She opened it and left it up. It was her really rough, colourful zipper that been four, so Jack wanted to go back inside.
#
# ...
#
# They put the cereal on the butter. Mommy opened the bowl and took it to the living room. Mommy looked out the sugar, so Jack and Mommy cut the cereal. The cereal was now sticky. Mommy said, "No for Daddy to let's have a new cereal of cereal."
#
# They agreed
# ==================================================
#
# step 8800: train loss 1.5981, val loss 1.5733
#
# ==================================================
# GENERATED TEXT AT STEP 8800:
# ==================================================
# ! minded was a little girl who liked to play. One day, she saw a shiny new bird in the sky. It was so pretty that she wanted to fly.
#
# She ran outside to catch it, pushing it to her house and over. As she got ready, she quickly realized it was the show. She was so excited! It was so pretty, it was so pretty too! She hugged it tightly and gave it to her mom.
#
# Suddenly, the picture disappeared and it was bright. The end.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# ==================================================
#
# step 8900: train loss 1.5890, val loss 1.5675
#
# ==================================================
# GENERATED TEXT AT STEP 8900:
# ==================================================
# ! was a little girl. She had a belt. It was a special belt that shone brightly. She wanted to keep it safe.
#
# She happily grabbed the belt before the belt folded together. It fell asleep. She had a lot of fun playing with it.
#
# Mum went home and showed her the belt to her house.
#
# The belt made the belt smooth. It made lots of sparkly silver and bright. The belt opened and smiled. It made everything look very unique with bright and smooth.
#
# The belt was very happy. It smiled and kept going with her belt.
#
# But then something amazing happened. It flew back to the room, in the belt and forth and forth. Jane was afraid, but she could not find the belt. She felt so envious.
#
# A little girl came to visit the belt. She noticed that the belt was not so serious. She just heard her wish come true and stopped at the belt!<|endoftext|><|endoftext|><|endoftext|>
# ==================================================
#
# step 9000: train loss 1.5972, val loss 1.5665
#
# ==================================================
# GENERATED TEXT AT STEP 9000:
# ==================================================
# ! was so excited, he wanted to go for a jog. He arrived and saw lots of old things. He wanted to explore the world, so he packed up his backpack with all his fun adventure. But one day, he saw a large lake for him. It was filled with big rocks. He could not believe his eyes. He looked around, but the water was heavy. He was scared, so he had a plan to stay. He went outside to explore the lake, looking for some rocks. Finally, he came out one of the lake. He said goodbye to the lake. He was so happy, he stayed in his shallow, yellow dandelgedghed his arms in the lake until he was safe in the lake.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# ==================================================
#
# step 9100: train loss 1.5903, val loss 1.5630
#
# ==================================================
# GENERATED TEXT AT STEP 9100:
# ==================================================
# ! He was playing in the park. He saw a cat running after. He was so fast! He ran to the dog and held it tight. The cat skipped away with a big smile. He saw it and stared at it was funny. He just made a funny face. He wanted to play with it too, so he grabbed it and ran back to the dog and ran away. He zipped it around in the spring and played with it all day. He was very happy.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# ==================================================
#
# step 9200: train loss 1.5895, val loss 1.5587
#
# ==================================================
# GENERATED TEXT AT STEP 9200:
# ==================================================
# ! after was exploring the forest. Every day, Susan got his armchair in a tree. She examined it and marched inside.
#
# Suddenly, Susan heard an empty noise. He was scared and ran up to her. It was too late, but he was too big to move and it swept away. He didn't want to stop shouting.
#
# Suddenly, Sarah had an idea. She asked her mom for help and her mom, â€œWhat can you do?â€
#
# Her mom said, â€œNow remember to be careful. Maybe we can push it together and finish it to manage it!â€
#
# They passed by no time and soon Susan got to feel a little scared again. Her mom said, â€œOkay mom!â€
#
# From then on, Sarah and her mom always kept trying to control the best lawn at children.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# ==================================================
#
# step 9300: train loss 1.5871, val loss 1.5584
#
# ==================================================
# GENERATED TEXT AT STEP 9300:
# ==================================================
# ! was a little boy. He liked to travel. One day, he went to the park with his dad. He saw a man playing with swings and slides. The man smiled and said, "Hello, Daddy! Can you go there?"
#
# The man smiled and happily played with his cars too. He laughed and told him, "Yes, he is going on the slide all day!" Everyone was so excited to play.
#
# The man ran up the slide and down the slide. It was so much fun! The man said, "Great job's! You're the best."
#
# He went down the slide and slid down the slide. He went down the slide so fast he slid down the slide. He was so happy. He stayed up and down and slid down the slide again, happy to have a new friend.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# ==================================================
#
# step 9400: train loss 1.5786, val loss 1.5564
#
# ==================================================
# GENERATED TEXT AT STEP 9400:
# ==================================================
# ! was playing in the garden. He had never seen anything like it before! It was hard for him for he could almost get in.
#
# He wanted to eat the leaves! He quit chewing it up and spotted a scorpising trying to pick. He remembered it from his new home. He used the cloth to look everywhere.
#
# Johnny was so excited, he couldn't wait to start picking up the bookshelf from the house. He picked up it to see who was very sad.
#
# Mommy had an idea. She took him to the house and got all of his own books and bought him a yummy novel. Then the mommy took him to the floor to bed. "Mommy, can you please please have it?" she shouted.
#
# Mommy was so happy the sound of the light. She picked up the nail and threw it on the couch to lick his little brother's nice bookshelf. Everyone in the living room was happy and knew he
# ==================================================
#
# step 9500: train loss 1.5780, val loss 1.5528
#
# ==================================================
# GENERATED TEXT AT STEP 9500:
# ==================================================
# ! Mommy was just 3-year-old. Every day after dinner for dinner, Mommy would wake up on her breakfast and open apron. Mommy sat Little 3-year-old hands and watched as Mommy walked to the refrigerator. She saw lots of things inside the refrigerator. Mommy knew that Dad had to try it up and take a closer look. Dad demanded that it was very dangerous, because it could help us save the task any money he ate to make sure to take a look more money.
# At first time, Mommy and Daddy decided to help and give Lucy a special treat and find the refrigerator. Iceefped and sweet treat in the end. Then, mommy took Tommy's pan.
# The next day, Mommy and Dad went back to the kitchen and told him that there were all the best broccoli special broccoli he had ever seen.
# Little Max and Mommy enjoyed the delicious aroma together and had a yummy dinner together.
# ==================================================
#
# step 9600: train loss 1.5802, val loss 1.5502
#
# ==================================================
# GENERATED TEXT AT STEP 9600:
# ==================================================
# !my was eager to go for his new seat. Mommy was excited, so they went to the park. Mommy got in a button. The button was so smooth and felt like he couldn't wait to drive away.
#
# When they got home, Mommy asked Mommy, â€œCan we have an idea?â€
#
# So they went inside for a walk in the park. Mommy's eyes lit up and told them that the button was a friendly little puppy. Inside the store, Joey touched it and whistled his ears. He was so happy and thanked Mommy and Daddy for the puppy for her ride. Mommy hugged him tightly while and said, â€œWell done, Joey and try again, you can ride it!"
#
# Mommy and Mommy drove off to the park, laughing and singing and laughing. They played on the swings and ran around the park until it was time to go home. It was a
# ==================================================
#
# step 9700: train loss 1.5727, val loss 1.5469
#
# ==================================================
# GENERATED TEXT AT STEP 9700:
# ==================================================
# ! was so excited! He had a big ball and he couldn't wait to play it by his friends with them. He asked his friend if they could play the ball! His friend insisted they said yes. So he said yes and took a for his best. His friend laughed excitedly and ran outside to play games.
#
# After the ball, Tim was very tired because it made his friend both laughed. He went outside to play and went up and down and shouted, "Wow, I felt so happy! I did it!" But then he remembered that his friend wanted to play a game. The rude friend was walking around, so he chased after him.
#
# Max's friend smiled and said, "Sure! I found what you achieved today!" His owner laughed and said, "Let's play tag and playfully." Josh was happy that he blinked to open the goal. The ball was so much fun could play again!<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# ==================================================
#
# step 9800: train loss 1.5744, val loss 1.5461
#
# ==================================================
# GENERATED TEXT AT STEP 9800:
# ==================================================
# ! loves to measure the big box. It is so soft, mild it made a happy sound. Mom says, "Woof! It sounds like a long time." She takes the box to the living room. She says, "Today, do you slide, Mom, can I work for the box?" Mom shakes the box and said, "Yes, you can open the box!" They are very happy. They do not want to be helpful about how high it would curl like a place to the box for mom.
#
# He looks around and saw a dog with a rocket. It was white and furry brown and adorable. Spot liked it so much and likes to go to his collection. He liked the rocket. He liked dogs and the mystery too. He used his net to dig and pulled it out of the box. He put the box under the box and started to chew it back on the box. He did not like it. He tried to play with the box, but it was
# ==================================================
#
# step 9900: train loss 1.5612, val loss 1.5435
#
# ==================================================
# GENERATED TEXT AT STEP 9900:
# ==================================================
# ! family was an honest family. They liked to paint. Every day, they would raise their paint and blow them around the wall.
#
# One day, Mom sprinkled some paint on them. There did it! She was so excited when she put them on a special painting too. It was full of paint!
#
# Mom had made a pretend to paint a big yellow hill. She said, "It's beautiful painting to make them pretty." She put it in a beautiful blue paint and put the paint. Her drawings on yellow for her design to make bright hands. Abbie straight with a big yellow, and then brushes. Mom added some colors of paint, it was so bright and lovely. It was just how beautiful it was. It fit perfectly, clear and beautiful!" Jack was proud.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# ==================================================
#
# Training completed!
