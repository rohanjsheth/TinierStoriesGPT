# %% [markdown]
# <a href="https://colab.research.google.com/github/rohanjsheth/TinierStoriesGPT/blob/main/TinierStories_v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import LambdaLR

import sentencepiece as spm

from datasets import load_dataset

import multiprocessing

import math

simple_stories_datasets = load_dataset("SimpleStories/SimpleStories")
tiny_stories_datasets = load_dataset("roneneldan/TinyStories")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00007.parquet:   0%|          | 0.00/238M [00:00<?, ?B/s]
# data/train-00001-of-00007.parquet:   0%|          | 0.00/238M [00:00<?, ?B/s]
# data/train-00002-of-00007.parquet:   0%|          | 0.00/238M [00:00<?, ?B/s]
# data/train-00003-of-00007.parquet:   0%|          | 0.00/238M [00:00<?, ?B/s]
# data/train-00004-of-00007.parquet:   0%|          | 0.00/238M [00:00<?, ?B/s]
# data/train-00005-of-00007.parquet:   0%|          | 0.00/238M [00:00<?, ?B/s]
# data/train-00006-of-00007.parquet:   0%|          | 0.00/238M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2115696 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/21371 [00:00<?, ? examples/s]
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00004-2d5a1467fff108(…):   0%|          | 0.00/249M [00:00<?, ?B/s]
# data/train-00001-of-00004-5852b56a2bd28f(…):   0%|          | 0.00/248M [00:00<?, ?B/s]
# data/train-00002-of-00004-a26307300439e9(…):   0%|          | 0.00/246M [00:00<?, ?B/s]
# data/train-00003-of-00004-d243063613e5a0(…):   0%|          | 0.00/248M [00:00<?, ?B/s]
# data/validation-00000-of-00001-869c898b5(…):   0%|          | 0.00/9.99M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2119719 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/21990 [00:00<?, ? examples/s]

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

vocab_size=512
n_sub_embd = 40
n_embd = 64
block_size = 512
dropout = 0.05
n_head = 8
num_kv = 4 #For grouped multiheaded
n_layer = 5
max_epochs = 1
batch_size = 64
batch_eval_interval = 100
eval_iterations = 10
feedforward_mulitple = 3
learning_rate = 1e-3
weight_decay = 0.01
beta2 = 0.99
# Out:
# cuda

# %%
cpu_cores = multiprocessing.cpu_count()
print(f'Available cpu cores: {cpu_cores}')
# Out:
# Available cpu cores: 12

# %%
train_dataset = tiny_stories_datasets['train']['text']
val_dataset = tiny_stories_datasets['validation']['text']

# %%
#If tokenizer doesn't exist, create tokenizer
spm.SentencePieceTrainer.train(
    sentence_iterator=iter(train_dataset),
    model_prefix='my_model',
    vocab_size=vocab_size,
    character_coverage=1.0,
    model_type='bpe',
    num_threads=cpu_cores,
    train_extremely_large_corpus=True,
    max_sentence_length=4192,
    input_sentence_size=10000000
)

# %%
tokenizer = spm.SentencePieceProcessor(model_file='my_model.model')

# %%
tokenizer.encode("Hello")
# Out:
# [61, 53, 374]

# %%
class Stories(Dataset):
    def __init__(self, dataset, sentence_tokenizer, block_size):
        self.dataset = dataset
        self.sentence_tokenizer = sentence_tokenizer
        self.block_size = block_size

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        text = self.dataset[idx]

        encoded = self.sentence_tokenizer.encode(text)

        if len(encoded) > self.block_size + 1:
            encoded = encoded[:self.block_size + 1]
        else:
            encoded = encoded + [0] * (self.block_size + 1 - len(encoded))

        return torch.tensor(encoded, dtype=torch.long)

# %%
def get_batch_values(batch):
  x = batch[:, :-1].contiguous()
  y = batch[:, 1:].contiguous()
  return x.to(device), y.to(device)

# %%
# ============================================================================
# FEEDFORWARD LAYERS
# ============================================================================

class ReLUFeedForward(nn.Module):
    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, feedforward_mulitple * n_embd, bias=False),
            nn.ReLU(),
            nn.Linear(feedforward_mulitple * n_embd, n_embd, bias=False),
            nn.Dropout(dropout)
        )
    def forward(self, x):
        return self.net(x)

class SwiGLUFeedForward(nn.Module):
  def __init__(self, n_embd):
      super().__init__()
      self.w1 = nn.Linear(n_embd, feedforward_mulitple * n_embd, bias=False)
      self.activation = nn.SiLU()
      self.w2 = nn.Linear(feedforward_mulitple * n_embd, n_embd, bias=False)
      self.w3 = nn.Linear(n_embd, feedforward_mulitple * n_embd, bias=False)
      self.dropout = nn.Dropout(dropout)

  def forward(self, x):
      gate = self.w1(x)
      gate = self.activation(gate)

      out = self.w3(x)
      out = out * gate
      out = self.w2(out)

      out = self.dropout(out)

      return out


# ============================================================================
# BASIC ATTENTION HEADS
# ============================================================================

class Head(nn.Module):
  def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)

        self.register_buffer("tril", torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

  def forward(self, x):
      B,T,C = x.shape

      k = self.key(x)
      q = self.query(x)
      v = self.value(x)

      weight = q @ k.transpose(-2, -1) #swaps the last two dimensions for transpose
      weight = weight * k.shape[-1]**-0.5 #scaling by size
      weight = weight.masked_fill(self.tril[:T, :T] == 0, float('-inf')) #masked fill to hide next tokens
      weight = torch.softmax(weight, dim=-1) #softmax across row
      weight = self.dropout(weight)

      out = weight @ v
      return out

class MultiHeadedAttention(nn.Module):
  def __init__(self, num_heads, head_size):
      super().__init__()
      self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
      self.proj = nn.Linear(num_heads * head_size, n_embd, bias=False)
      self.dropout = nn.Dropout(dropout)

  def forward(self, x):
      out = torch.cat([head(x) for head in self.heads], dim=-1)
      out = self.proj(out)
      out = self.dropout(out)
      return out


# ============================================================================
# GROUPED QUERY ATTENTION HEADS
# ============================================================================

class GroupedHead(nn.Module):
  def __init__(self, head_size, key, value):
        super().__init__()
        self.key = key
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = value

        self.register_buffer("tril", torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

  def forward(self, x):
      B,T,C = x.shape

      k = self.key(x)
      q = self.query(x)
      v = self.value(x)

      weight = q @ k.transpose(-2, -1) #swaps the last two dimensions for transpose
      weight = weight * k.shape[-1]**-0.5 #scaling by size
      weight = weight.masked_fill(self.tril[:T, :T] == 0, float('-inf')) #masked fill to hide next tokens
      weight = torch.softmax(weight, dim=-1) #softmax across row
      weight = self.dropout(weight)

      out = weight @ v
      return out

class GroupedMultiHeadedAttention(nn.Module):
  def __init__(self, num_heads, head_size, num_kv):
      super().__init__()
      heads_per_kv = num_heads//num_kv
      self.keys = nn.ModuleList([nn.Linear(n_embd, head_size, bias=False) for _ in range(num_kv)])
      self.values = nn.ModuleList([nn.Linear(n_embd, head_size, bias=False)for _ in range(num_kv)])
      self.heads = nn.ModuleList([
                                    GroupedHead(head_size, self.keys[idx//heads_per_kv], self.values[idx//heads_per_kv])
                                    for idx in range(num_heads)
                                    ])
      self.proj = nn.Linear(num_heads * head_size, n_embd, bias=False)
      self.dropout = nn.Dropout(dropout)

  def forward(self, x):
      out = torch.cat([head(x) for head in self.heads], dim=-1)
      out = self.proj(out)
      out = self.dropout(out)
      return out


# ============================================================================
# ROPE UTILITIES
# ============================================================================


def precompute_freqs_cis(dim: int, end: int, theta: float = 10000.0):
    freqs = 1.0 / (theta ** (torch.arange(0, dim, 2)[: (dim // 2)].float() / dim))
    t = torch.arange(end, device=freqs.device)
    freqs = torch.outer(t, freqs).float()
    freqs_cos = torch.cos(freqs)  # real part
    freqs_sin = torch.sin(freqs)  # imaginary part
    return freqs_cos, freqs_sin

def reshape_for_broadcast(freqs_cis: torch.Tensor, x: torch.Tensor):
    ndim = x.ndim
    T = x.shape[1]  # actual sequence length

    freqs_cis = freqs_cis[:T]

    shape = [d if i == 1 or i == ndim - 1 else 1 for i, d in enumerate(x.shape)]
    shape[-1] = freqs_cis.shape[-1]
    return freqs_cis.view(shape)

def apply_rotary_emb(
    xq: torch.Tensor,
    xk: torch.Tensor,
    freqs_cos: torch.Tensor,
    freqs_sin: torch.Tensor
) -> tuple[torch.Tensor, torch.Tensor]:
    # Fix: Ensure head_dim is even
    *_, head_dim = xq.shape
    assert head_dim % 2 == 0, f"Head dimension {head_dim} must be even for RoPE"

    # Reshape to split into real and imaginary parts
    xq_r, xq_i = xq.float().reshape(xq.shape[:-1] + (-1, 2)).unbind(-1)
    xk_r, xk_i = xk.float().reshape(xk.shape[:-1] + (-1, 2)).unbind(-1)

    # Reshape freqs for broadcasting
    freqs_cos = reshape_for_broadcast(freqs_cos, xq_r)
    freqs_sin = reshape_for_broadcast(freqs_sin, xq_r)

    # Apply rotation
    xq_out_r = xq_r * freqs_cos - xq_i * freqs_sin
    xq_out_i = xq_r * freqs_sin + xq_i * freqs_cos
    xk_out_r = xk_r * freqs_cos - xk_i * freqs_sin
    xk_out_i = xk_r * freqs_sin + xk_i * freqs_cos

    # Flatten back to original shape
    xq_out = torch.stack([xq_out_r, xq_out_i], dim=-1).reshape(xq.shape)
    xk_out = torch.stack([xk_out_r, xk_out_i], dim=-1).reshape(xk.shape)

    return xq_out.type_as(xq), xk_out.type_as(xk)


# ============================================================================
# ROPE ATTENTION HEADS
# ============================================================================

class RoPEGroupedHead(nn.Module):
    def __init__(self, head_size, key, value, block_size):
        super().__init__()
        self.key = key
        self.query = nn.Linear(64, head_size, bias=False)  # n_embd hardcoded for clarity
        self.value = value
        self.head_size = head_size

        self.register_buffer("tril", torch.tril(torch.ones(block_size, block_size)))
        self.dropout = nn.Dropout(0.05)

    def forward(self, x, freqs_cos, freqs_sin):
        B, T, C = x.shape

        k = self.key(x)
        q = self.query(x)
        v = self.value(x)

        if self.head_size % 2 == 0:
            q, k = apply_rotary_emb(q, k, freqs_cos, freqs_sin)

        weight = q @ k.transpose(-2, -1)
        weight = weight * k.shape[-1]**-0.5
        weight = weight.masked_fill(self.tril[:T, :T] == 0, float('-inf'))
        weight = torch.softmax(weight, dim=-1)
        weight = self.dropout(weight)

        out = weight @ v
        return out

class RoPEGroupedMultiHeadedAttention(nn.Module):
    def __init__(self, num_heads, head_size, num_kv, n_embd, block_size):
        super().__init__()
        heads_per_kv = num_heads // num_kv
        self.keys = nn.ModuleList([nn.Linear(n_embd, head_size, bias=False) for _ in range(num_kv)])
        self.values = nn.ModuleList([nn.Linear(n_embd, head_size, bias=False) for _ in range(num_kv)])
        self.heads = nn.ModuleList([
            RoPEGroupedHead(head_size, self.keys[idx//heads_per_kv], self.values[idx//heads_per_kv], block_size)
            for idx in range(num_heads)
        ])
        self.proj = nn.Linear(num_heads * head_size, n_embd, bias=False)
        self.dropout = nn.Dropout(0.05)

    def forward(self, x, freqs_cos, freqs_sin):
        out = torch.cat([head(x, freqs_cos, freqs_sin) for head in self.heads], dim=-1)
        out = self.proj(out)
        out = self.dropout(out)
        return out


# ============================================================================
# TRANSFORMER BLOCKS
# ============================================================================

class Block(nn.Module):
  def __init__(self, n_embd, n_head):
    super().__init__()
    head_size = n_embd // n_head
    self.attn = MultiHeadedAttention(n_head, head_size)
    self.ffwd = SwiGLUFeedForward(n_embd)
    self.ln1 = nn.LayerNorm(n_embd)
    self.ln2 = nn.LayerNorm(n_embd)

  def forward(self, x):
        x = x + self.attn(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

class GroupedBlock(nn.Module):
  def __init__(self, n_embd, n_head, num_kv):
    super().__init__()
    head_size = n_embd // n_head
    self.attn = GroupedMultiHeadedAttention(n_head, head_size, num_kv)
    self.ffwd = SwiGLUFeedForward(n_embd)
    self.RMSn1 = nn.RMSNorm(n_embd)
    self.RMSn2 = nn.RMSNorm(n_embd)

  def forward(self, x):
        x = x + self.attn(self.RMSn1(x))
        x = x + self.ffwd(self.RMSn2(x))
        return x

class RoPEGroupedBlock(nn.Module):
    def __init__(self, n_embd, n_head, num_kv, block_size):
        super().__init__()
        head_size = n_embd // n_head
        self.attn = RoPEGroupedMultiHeadedAttention(n_head, head_size, num_kv, n_embd, block_size)
        self.ffwd = SwiGLUFeedForward(n_embd)
        self.ln1 = nn.RMSNorm(n_embd)
        self.ln2 = nn.RMSNorm(n_embd)

    def forward(self, x, freqs_cos, freqs_sin):
        x = x + self.attn(self.ln1(x), freqs_cos, freqs_sin)
        x = x + self.ffwd(self.ln2(x))
        return x

# %%
class GPT(nn.Module):

    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_sub_embd, bias=False)
        self.token_proj_layer_up = nn.Linear(n_sub_embd, n_embd, bias=False)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)],
            nn.LayerNorm(n_embd)
        )

        self.token_proj_layer_down = nn.Linear(n_embd, n_sub_embd)

        self.lm_head = nn.Linear(n_sub_embd, vocab_size, bias=False)
        self.lm_head.weight = self.token_embedding_table.weight #sharing embeddings

    def forward(self, idx, targets=None):

        # idx and targets are both (B,T) tensor of integers
        B, T = idx.shape

        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        tok_emb = self.token_proj_layer_up(tok_emb)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device))
        x = tok_emb + pos_emb
        x = self.blocks(x)
        x = self.token_proj_layer_down(x)
        logits = self.lm_head(x)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -block_size:]
            logits, loss = self(idx_cond)
            logits = logits[:, -1, :]
            probs = F.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx

# %%
class GroupedGPT(nn.Module):

    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        #self.token_proj_layer_up = nn.Linear(n_sub_embd, n_embd, bias=False)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)

        self.blocks = nn.Sequential(*[GroupedBlock(n_embd, n_head, num_kv) for _ in range(n_layer)],
            nn.RMSNorm(n_embd)
        )

        self.token_proj_layer_down = nn.Linear(n_embd, n_sub_embd, bias=False)

        self.lm_head = nn.Linear(n_embd, vocab_size, bias=False)
        self.lm_head.weight = self.token_embedding_table.weight #sharing embeddings

    def forward(self, idx, targets=None):

        # idx and targets are both (B,T) tensor of integers
        B, T = idx.shape

        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        tok_emb = self.token_proj_layer_up(tok_emb)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device))
        x = tok_emb + pos_emb
        x = self.blocks(x)
        x = self.token_proj_layer_down(x)
        logits = self.lm_head(x)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -block_size:]
            logits, loss = self(idx_cond)
            logits = logits[:, -1, :]
            probs = F.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx

# %%
class RoPEGroupedGPT(nn.Module):
    def __init__(self):
        super().__init__()
        self.block_size = block_size
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        #self.token_proj_layer_up = nn.Linear(n_sub_embd, n_embd, bias=False)

        self.blocks = nn.ModuleList([
            RoPEGroupedBlock(n_embd, n_head, num_kv, block_size)
            for _ in range(n_layer)
        ])
        self.final_norm = nn.RMSNorm(n_embd)

        #self.token_proj_layer_down = nn.Linear(n_embd, n_sub_embd, bias=False)
        self.lm_head = nn.Linear(n_embd, vocab_size, bias=False) #
        self.lm_head.weight = self.token_embedding_table.weight

        head_dim = n_embd // n_head
        if head_dim % 2 != 0:
            raise ValueError(f"Head dimension {head_dim} must be even for RoPE. Adjust n_embd or n_head.")

        freqs_cos, freqs_sin = precompute_freqs_cis(head_dim, block_size)
        self.register_buffer("freqs_cos", freqs_cos, persistent=False)
        self.register_buffer("freqs_sin", freqs_sin, persistent=False)

    def forward(self, idx, targets=None):
        device = idx.device
        B, T = idx.shape

        tok_emb = self.token_embedding_table(idx)
        #tok_emb = self.token_proj_layer_up(tok_emb)

        x = tok_emb

        freqs_cos = self.freqs_cos[:T]
        freqs_sin = self.freqs_sin[:T]

        for block in self.blocks:
            x = block(x, freqs_cos, freqs_sin)

        x = self.final_norm(x)
        #x = self.token_proj_layer_down(x)
        logits = self.lm_head(x)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
      for _ in range(max_new_tokens):
          idx_cond = idx[:, -self.block_size:]
          logits, loss = self(idx_cond)
          logits = logits[:, -1, :]
          probs = F.softmax(logits, dim=-1)
          idx_next = torch.multinomial(probs, num_samples=1)
          idx = torch.cat((idx, idx_next), dim=1)
      return idx

# %%
model = RoPEGroupedGPT().to(device)

total_params = sum(p.numel() for p in model.parameters())
print(f"Total parameters: {total_params}")

print(model)

train_data = Stories(train_dataset, tokenizer, block_size)
val_data = Stories(val_dataset, tokenizer, block_size)
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False)

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=learning_rate,
    weight_decay=weight_decay,
    betas=(0.9, beta2)
)

def get_karpathy_lr_lambda(warmup_iters=1000, lr_decay_iters=80000, min_lr_ratio=0.1):
    def lr_lambda(current_step):
        if current_step < warmup_iters:
            return current_step / warmup_iters
        elif current_step > lr_decay_iters:
            return min_lr_ratio
        else:
            decay_ratio = (current_step - warmup_iters) / (lr_decay_iters - warmup_iters)
            coeff = 0.5 * (1.0 + math.cos(math.pi * decay_ratio))
            return min_lr_ratio + coeff * (1.0 - min_lr_ratio)
    return lr_lambda

scheduler = LambdaLR(optimizer, lr_lambda=get_karpathy_lr_lambda(
    warmup_iters=1000,
    lr_decay_iters=80000,
    min_lr_ratio=0.1
))
# Out:
# Total parameters: 279232
# RoPEGroupedGPT(
#   (token_embedding_table): Embedding(512, 64)
#   (blocks): ModuleList(
#     (0-4): 5 x RoPEGroupedBlock(
#       (attn): RoPEGroupedMultiHeadedAttention(
#         (keys): ModuleList(
#           (0-3): 4 x Linear(in_features=64, out_features=8, bias=False)
#         )
#         (values): ModuleList(
#           (0-3): 4 x Linear(in_features=64, out_features=8, bias=False)
#         )
#         (heads): ModuleList(
#           (0-7): 8 x RoPEGroupedHead(
#             (key): Linear(in_features=64, out_features=8, bias=False)
#             (query): Linear(in_features=64, out_features=8, bias=False)
#             (value): Linear(in_features=64, out_features=8, bias=False)
#             (dropout): Dropout(p=0.05, inplace=False)
#           )
#         )
#         (proj): Linear(in_features=64, out_features=64, bias=False)
#         (dropout): Dropout(p=0.05, inplace=False)
#       )
#       (ffwd): SwiGLUFeedForward(
#         (w1): Linear(in_features=64, out_features=192, bias=False)
#         (activation): SiLU()
#         (w2): Linear(in_features=192, out_features=64, bias=False)
#         (w3): Linear(in_features=64, out_features=192, bias=False)
#         (dropout): Dropout(p=0.05, inplace=False)
#       )
#       (ln1): RMSNorm((64,), eps=None, elementwise_affine=True)
#       (ln2): RMSNorm((64,), eps=None, elementwise_affine=True)
#     )
#   )
#   (final_norm): RMSNorm((64,), eps=None, elementwise_affine=True)
#   (lm_head): Linear(in_features=64, out_features=512, bias=False)
# )

# %%
def evaluate_model():
    out = {}
    model.eval()

    with torch.no_grad():

        train_losses = torch.zeros(eval_iterations)
        train_iter = iter(train_loader)
        for k in range(eval_iterations):
            try:
                batch = next(train_iter)
            except StopIteration:
                train_iter = iter(train_loader)
                batch = next(train_iter)
            xb, yb = get_batch_values(batch)
            logits, loss = model(xb, yb)
            train_losses[k] = loss.item()
        out['train'] = train_losses.mean()

        val_losses = torch.zeros(eval_iterations)
        val_iter = iter(val_loader)
        for k in range(eval_iterations):
            try:
                batch = next(val_iter)
            except StopIteration:
                val_iter = iter(val_loader)
                batch = next(val_iter)
            xb, yb = get_batch_values(batch)
            logits, loss = model(xb, yb)
            val_losses[k] = loss.item()
        out['val'] = val_losses.mean()

        # Generate Sample
        prompt = "Jack and Jill went"
        tokenized_prompt = torch.tensor(tokenizer.encode(prompt)).unsqueeze(0).to(device)

        sample_gen = model.generate(tokenized_prompt, 200)
        sample_gen = tokenizer.decode(sample_gen[0].tolist())

        out['sample_gen'] = sample_gen

    model.train()
    return out

# %%
for epoch in range(max_epochs):
    for batch_idx, batch in enumerate(train_loader):
        x, y = get_batch_values(batch)

        logits, loss = model(x, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()

        if batch_idx % batch_eval_interval == 0 or batch_idx == 0:
          results = evaluate_model()
          print("================================================================================")
          print(f"Epoch {epoch} | Batch {batch_idx} | Train Loss {results['train']} | Validation Loss {results['val']}")
          print(f"Sampled Text:")
          print(results['sample_gen'])
          print("================================================================================")
# Out:
# ================================================================================
# Epoch 0 | Batch 0 | Train Loss 38.02457046508789 | Validation Loss 34.58747482299805
# Sampled Text:
# Jack and Jill went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 100 | Train Loss 17.890174865722656 | Validation Loss 16.156208038330078
# Sampled Text:
# Jack and Jill went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went went
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 200 | Train Loss 7.796545505523682 | Validation Loss 7.1947784423828125
# Sampled Text:
# Jack and Jill went too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too too..... too too too too too too too too too too too too too too too too too too too too too.....umumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumumssssss......one too too too too la la la la la la la la la la la la la excited excited excitedunununun
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 300 | Train Loss 5.5210771560668945 | Validation Loss 5.0852179527282715
# Sampled Text:
# Jack and Jill went~ theing reo help help help help it t sawyo M aririanara the and and Mom Momt backz momrie.art mom mom momind it it reigigigig and4 e help help help. loo loorysâick. saws‡‡ plillâ was u. little little little itryart laum blryter too her He A little e." came notn‡‡‡‡ and the pr dundd the u started started started named helpck. coidedan‡y t1vimeime say say say fl, and and and]]] little~ u u u uhain.vedvedvedved.etet.t big He~ and and buteses theher exc c see foundununen found.nouldould the likeryryryry little an.~ameromromesÅ butarainginginging!"!"wes say say say say say
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 400 | Train Loss 4.468771934509277 | Validation Loss 4.0148725509643555
# Sampled Text:
# Jack and Jill wentf e. dry D away awayenout mom mom Ln a littlei Iara Mom ofy the ddkingn were do lavedvedved.tpp her was a itt was around to friendse t t. Aoud. wasould exc wase named thed. s. la sm wass. s car found la Heu foundutris fl. y y y y yar Theying allc?" herromromlyd u u ut excited D the found it. They4 little littleaould]]outW it, little and whenes, of ne Theyuo yugi th th. found found all Su loo the A o HeW boy. boyind laie cl d d co‡ the arJryry.ous the thentind saw reriedallous. He somets Dtt there itoutout back boy aa, around thesara happy thea str fl
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 500 | Train Loss 3.559215545654297 | Validation Loss 3.241175889968872
# Sampled Text:
# Jack and Jill went itii a s He Butillar andidevedvede all the r started alledo themside. d saw a little andone o man· heru D found' cl anden fun funart m mom that‡‡ and was a sisri flal excitedd fun to j O scg time‡ p ag help andgether have happyaonev butoutgfryun. lais Hey back little goting do wanted. Shead walri. The mom. callTi cingsan re decided found hisri u Lily said,at. Theec too. Shei mom. someti aaenallh that ex. He saysa go ag these the c sh it was thereone dm a ex»pp getf nekemss dingaking to atetstwtingouldena. gotedp toing.art. "ououan said. Thest
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 600 | Train Loss 2.980797290802002 | Validation Loss 2.7078447341918945
# Sampled Text:
# Jack and Jill wentsen to t Aering. The smes and hisaraest there thene. Theyle leu cast. He said,ppuort uu in was a m the w momh likeas the p ofound. Af bueople said she had neaaleshp€ Suterug aing,tt the it. They r outoi gumals. They said, butse with her dotaf likeickk shs. The with her mom Mry anded w were sout bor what. Ituy things foris pl st felt wasoc f veryuck in made apes. He the Su p a best lovedill and makes of thear. He would. He wal Heatesten back. He re a want to big withs with‡ings,.Pplrom thatid Timmy was, they whob sondf
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 700 | Train Loss 2.6103367805480957 | Validation Loss 2.3836867809295654
# Sampled Text:
# Jack and Jill went play ' up it. She had s woetter l Aft little girles. He way and away. Soild bull,elling. It They gard. Heer. ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 800 | Train Loss 2.4420599937438965 | Validation Loss 2.2236058712005615
# Sampled Text:
# Jack and Jill went‡ in the founding li~ it, "Nellust. Heie to the back help with had to draged her. Ampp! I will. Herful his andightingreing b specore andeetother the cick and his b kra th Lilyhed the together let want with it. "uck! la nhingx away, up and he fon ofide. Lily'ank hims and You said said they had dric d treots her orr friendly.ful by was smellcket very verymst loud thisy fast of you,- it a she seeing youill I decided house untndf the disk Job."ongned. su st why "Wow, sch thecy. Ar unf m any but he had d shoutm little
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 900 | Train Loss 2.3714756965637207 | Validation Loss 2.123445510864258
# Sampled Text:
# Jack and Jill went toay ang pce, als seed, "Iturn. "It mom isPoer thisiner was so." Mr toyent atd "Thlories, Apped mom said. The coame and dumpr like the big run and wanted to the tr Tim. The ye Timmyll. riecia willing and were gofnn, theter wgen. Buns mu him and beahing to help you beloick a pleanageagkone have up. He wanted to make ang fl shget, being on the her bore the buen all the b excited. Lily Lily wasst say happy. Hery he wasy sto made her excited to b," said, but very want touckh proud. After. He wanted to see hig its the brought
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 1000 | Train Loss 2.3217036724090576 | Validation Loss 2.0396556854248047
# Sampled Text:
# Jack and Jill went back lotound. She go to the sunatant and dad long birdsh. One day spother. Jency ande, Jill hiscat and peop no it's. He put to hatient the pinallys and says. You are like see what as the dager?" Ace to by that'sing the too. Sara decided to rane sprongints for fellacz fellshide. is fun sca said, the do you, "Mb came as he. The trate. "Canfy, "Ited the ser ping sl. He gent with abartoon. He higgedderi say,ave to go home. But the nice." Sarah!" Sudden would she did not tight. She sw
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 1100 | Train Loss 2.174362897872925 | Validation Loss 1.9651542901992798
# Sampled Text:
# Jack and Jill went from areed down with sheds. The how pield was very brankunat say her do from the go them. Sheong you old man car andld her to the stor. The bird wireat and saw rice and it home. She went for her took forguile smiled and graile. She hander a cuppet, Ben with asked the back theld many for back. The pill, but the ball thereon clo "I de shss. He saw she stayf the on his. The big overy too you have to com. He thanjoonh. She door!" Bil hearnkeying the wood andht away. They's heroth like dly grapes, blue an pom,." Her'm perea
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 1200 | Train Loss 2.121964454650879 | Validation Loss 1.8906853199005127
# Sampled Text:
# Jack and Jill went outside, "Lookarentila is Mamily. They ca is eather." Joh for his friends, thereie. "Thlele, so prinh is a wavise said. Men waged na p get it and had a fily. But ask at thearsed with that got to her play together was things to go. "This loved to the behook, found new friendch solapry. "Wh loved it as sce?" the new fast thought theirved. I'm go to play inside and with his mom so happy. When she had something cright came outside Suddyally go and their let's in hand. Annached the jum of his clo the blusantusicted to ise hug. It doing it
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 1300 | Train Loss 2.051809787750244 | Validation Loss 1.8170576095581055
# Sampled Text:
# Jack and Jill went for a tes and a spoming a chax smiled their toy and a mommy, so run play. Ben felt something mayed to the park happy and see what it cuest? Benn't rollter and the box was a chull Tom noisy clonderaskop num strong gran laad. Tom had a lost down their momâ€œHe in the sun happaf. She looked up at very red to sperful." But, "Lo." Tom cloud sunkter. I found a it're specre coming happin, to signk dad." They have his saned her mom said from more a spavoure storry. Tommy he was alre be compen th0 and cate we det them his going his
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 1400 | Train Loss 1.9523006677627563 | Validation Loss 1.7486804723739624
# Sampled Text:
# Jack and Jill went hay so sad. They not a little boy couldn't didn't are oramard. He knew on the playing it was done when he wasn't know around and had over and said "It's a bal to box. In open, Jack cuted like told. The might, "Mat let's shin courinally," Sat and hate and enoughy kids. Jack hount. Jack decided to tigkess in the hunes. He fell back and discted something. He keful jired. He decided to go up beet to come back. He very right to the around, Jack was very teant. He made a first flowed and grmet and as am
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 1500 | Train Loss 1.8562818765640259 | Validation Loss 1.6805099248886108
# Sampled Text:
# Jack and Jill went something tookes!" he wanted to the storester. He went to the cars cups back to the strass. He put onem is day, oruck idea. It was a little been fix light. Jack was to box. Jack decided to get hoods. He thought it again asbed and do not breing around like its to until. He turts been scapes, but he was kite alone and go around to her. Suddenly, "Noe, new on the kitchenow, could tree to you brother of sear. "Let laughing like it is belough of food boxs you that like the big cruck? When it said, "Nos. We loved the lear everyone
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 1600 | Train Loss 1.8285493850708008 | Validation Loss 1.6234954595565796
# Sampled Text:
# Jack and Jill went to his toys. They would do their toys, learing her he was around and and he was ever. So there was eather, Jack that he said, "What's very never orn, but you are you untilse gy, but a mom saw the turn hops and said. The little girl was not to shoppleane and said "Canse. To from until the world." Jack wanted to not safe crying. He telled it and said, "You't see, whit mould ben you say. But thinone, and war to be happy and her?" Jack asked the need. Sned it, "That's go to her mom. Jacked from her wal." Jack said, "My at the water for giv
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 1700 | Train Loss 1.7916332483291626 | Validation Loss 1.5771658420562744
# Sampled Text:
# Jack and Jill went to a big singeron. mordan it was scared and sats of a collect out of brightery and houred on it. "I made a swer?" Tim hounts closer and meues a stick hidhard. Mom people first agreett and zip and a powf in the stasure hort!" Timmy said and replained his have dad on the smiles inneoring. He said, "I'm sthers and will gif up. "Or this around my some courride, itad. "It's a Frouse for me, but he?" Mommy mom smiled and he watched it for a big pionch buries bee I want to sho
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 1800 | Train Loss 1.6841274499893188 | Validation Loss 1.5351675748825073
# Sampled Text:
# Jack and Jill went to loud. They were waited, "But mine with you. ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 1900 | Train Loss 1.6763877868652344 | Validation Loss 1.4977080821990967
# Sampled Text:
# Jack and Jill went inirl. They saw their a big dark box. They were big to star hard. They pushed Every day, at the birds drive and weaken. It was very fast. She was a bushing how to rub Jack. She was joined. But Soon. She wanted to cow it. Amy at her mommy and runked to a han. They were walking and wanted to see them. It was so happy for down. Mommy smiled and told her kept yards on the warm step crerow as she thanked them. It looked h and store to the dog. "We looks ogenn and Lucy grabw with loud towel made big and make bare no mutes. Jan
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 2000 | Train Loss 1.6678352355957031 | Validation Loss 1.467068076133728
# Sampled Text:
# Jack and Jill went outside through their a pigures'dc's eired he, he couldt visit a special bird a broket and he seeme lost hours. Then that was very right. He had his. "Can we creature look ats and wind again! It smovued, Jack and can show Sam stufies for help. He started to water and flowers, "Hi?" Jack told his go to "Mom, Jack are curious." As the buice thick what it? Neetie were imprassed. He put it out of the colorful with the different how. He was sad because he ran owning the waves
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 2100 | Train Loss 1.584977626800537 | Validation Loss 1.4407445192337036
# Sampled Text:
# Jack and Jill went outside to play with him. He saw, your new things he tight in the floor. He asked him. He did not like the comb of them. He picked it up, but he went on your ready and down too long bucket. She nodded and poin with the brave. He tried to heard a long frick the bath and higher Benny. He poined the dinh. Suddenly, he ancomlary smilone started to road. He gone his delicatle. He was kaying back, the newm. He smiles said to Mrb the flole, "Wow! You not go! After a moments selly jour of aboutf. It's this didter. I see
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 2200 | Train Loss 1.6043586730957031 | Validation Loss 1.4187349081039429
# Sampled Text:
# Jack and Jill went outside with ten. She boats the cat was water and should take a sweet. With mark, she come back to cuots and turn from her friends. He wanted to share his friend. When the yummy had an opensasted. Maybach. She were very safesy. Lolf! The meaze heard a it was scried. She said, "I am, little girl, And the idea, they brought it me like a castle of the story!" "There said: "I made a stock, soe that sometimes setter!" Mommy smiled. The old man said he sparked it out him to hid the dark. He looked around, but he could not hop cheere
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 2300 | Train Loss 1.554776668548584 | Validation Loss 1.394433856010437
# Sampled Text:
# Jack and Jill went outside. They like to rain muden hoping four bright and wipfuy was. "Wow, mom?" they decided to help you drink again. She took a little people jour reymind down," Soon surprised. She tried. She went to Ben and said to Ben, "It's okay! It's enough the team. Jack was very kind and made a crandrman on it. "You did not lost listen and my chirst". The pondld tightly and a duckss, about some read." Jack said with the trup and whisples on the kidst never having like the voice".
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 2400 | Train Loss 1.5674432516098022 | Validation Loss 1.3789952993392944
# Sampled Text:
# Jack and Jill went and began to help the car. "What is bicy." So ostay here. You can on it again loos atay." The hid lion. Maybe sacked apple hold the new pybble and measuresf to play with patch. ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 2500 | Train Loss 1.5107094049453735 | Validation Loss 1.3604339361190796
# Sampled Text:
# Jack and Jill went to the paper. One day, it was playing in the beach. He saw a big red cake it at it. He wanted to play with his wind rains that she was crayet. He was sad and shouted that it had he wouldn't need to stop. He thought a tag and made m said he were able to celebroon. He was scared they had an idea. Jack knew the help, he timo was but he didn't wait. When he continued his forest. Jack as his mum told his room and choureed it. The safcy was about mud and started to. Jack followed that he knew shrug. The dorable beautiful br
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 2600 | Train Loss 1.526309609413147 | Validation Loss 1.3456591367721558
# Sampled Text:
# Jack and Jill went together to the park most inside. Jack replied a walk in and two mirrors were ear. As they put the try and tried to spigge of the jur of it! Jangie had a lunch, a p boy called over to Sambross a tree who seem. Sam felt so trying playing, so they were a big rube with a creat scared. The bunny was excited that he could watch his colorful wondered it liked the trees. He rid so leaizin when he resten sweet and promised to clean on an unize. He would limy preone around the ground. So, Jack and said, "Moral show
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 2700 | Train Loss 1.4936378002166748 | Validation Loss 1.3327138423919678
# Sampled Text:
# Jack and Jill went off the animals one in the woods. He saw a big hrocogt when a mupy lots of rooms and it very perfect and warm out on its kisss. The ball gather was very felt he said goodbye to the tree. Bob said, "It's a man teach me," the turtle smiled. Jack and Jack felt secret going, but he shouted jump and being girl and saw a lot of fun. He felt sad. Jack smiled and said, "What is smoother menes! You is new yoursp and fun!" Jack waved Sax continued! Everyone had a little girl and holded what was still? Jill and
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 2800 | Train Loss 1.452947974205017 | Validation Loss 1.320469617843628
# Sampled Text:
# Jack and Jill went on his toys. They wanted to stay a nube treal ball with the problem. One day, Jack wanted to go on his toy," she said. "It's family! But the colors. There are sad of me!" May asked Fink. "You should crying back to it. Tim thought it! "At is not hurt. I have some trumpy." Tim said, "I will res't like this twin. Everyone how for the teachern. I want to be fleated Jack. At to obsse her. The move Jack saw: "If you, mom?" The next-s. I love you, Jack and Jack's magical. He clapped
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 2900 | Train Loss 1.481961965560913 | Validation Loss 1.3085541725158691
# Sampled Text:
# Jack and Jill went to the park. But then he saw a big red called a mison tall. He became to help their comear la landed in the hand. He found many jug. He couldn't wait to measure. So he came to his nape with it and both made a loud noise. Jack was very excited that he kept going window. He never saw that his friends again. "Oh no!" The old for your blocks and said, "I'm too good friends, onday?" The what youam, Jill had anymore. He felt Beara came and said to their hand. "Oh I see there?" Jack smiled as they played and cry on the shiny leaves. Jack looked at his toy
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 3000 | Train Loss 1.4843755960464478 | Validation Loss 1.298760175704956
# Sampled Text:
# Jack and Jill went to the park. Jill went and then he saw something bike. He said it was scared and saw a big heal. He smiled and looked up her clums around and saw it in his own. After using his bright shape. When he realized it was too hungry to join it. His dad got happy and gave him a while, he thought off everyone. He thanked the words! ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 3100 | Train Loss 1.4264086484909058 | Validation Loss 1.2911193370819092
# Sampled Text:
# Jack and Jill went for a walk. He was sad behind away from it. He went home before the hill again, but it looked back away. He smiled and said they were slowly to his cat named Jack. Jack was very excited that he wanted to go something as the door. Jack got angry and down to Ben. Sam said no, "s hair, as you be careful. Let's ok for his mom! You gave them for drawered noise. mave." Jack started to feel better for lit up. He looked atting up and saw lots of fun. She ran to him. He said goodbye to the moral stuffy and catch Dake each other with just feel comfort everywag. He runardy sh
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 3200 | Train Loss 1.4593110084533691 | Validation Loss 1.2795909643173218
# Sampled Text:
# Jack and Jill went to the park. But then, he saw a big leadhey in the car, but as it was. It was black but up and saw something sitting on the key. Jack didn't like cow, so he put it back in the big,. Jack's big smile that, Sue's nearby, there was much fun to come trust toy. When the car was needed, he didn't feed too. She decided to wait out Daisy. She tried to store and said, "Hle, she openers!" They acceper and said, "Wel hear the doing pack. Fluffue are alone?" But So Jack went higher and best. The test and played in univerets
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 3300 | Train Loss 1.425944209098816 | Validation Loss 1.2721924781799316
# Sampled Text:
# Jack and Jill went to the farsts. He was an quiet! He likes to the big grass. But his picks in the strostumbles. It was something across that it's brother the tire in help. He climbed up and run away. He workeds to his smch drawl surprised and moved at it. Jack enjoyed the appeor closer. She was so excitedbendful. He started to come to play with his big met. "Don't worry, under the story, I couldn't have a flower that you did we made both smart in. At that it is mean to fis." The maygy was so thing to drank
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 3400 | Train Loss 1.402806282043457 | Validation Loss 1.2656691074371338
# Sampled Text:
# Jack and Jill went outside. Sam was having floor playing with a nail. He looked around with his birmore and came over. His mom smiled. He came to the park everywhere he got store. He did. He said, "Hello, little nice. Doant,!" Doilli was happy. He laughed and laughed and ran sometimes. He drove big,. He said "Sorry, I did?" His friends said, "This is seeing you hungry my clouds, I see your penny. I did. He drove steal and listen. The pretend spent, she had over another hime again. She waved goodbyed to have his motorite. John ever and So
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 3500 | Train Loss 1.4112746715545654 | Validation Loss 1.2574089765548706
# Sampled Text:
# Jack and Jill went to the park. He wanted to use her cland handle. So he arrived at the paw were at the fox as she had something bad. The triach then started to worry and before he decided to go to fix me on the door. Just then, he decided to catch the fisire, but into the tree. When the doll reached the voice as lunch started to yell. Jack agreed and his twirled, there was through the zoo up and moved. Jack promised to travel on his down near the park, white way again, then a nildren. He tch tight to be voice. The trunnel doct
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 3600 | Train Loss 1.3930904865264893 | Validation Loss 1.248820185661316
# Sampled Text:
# Jack and Jill went outside. He run drawing thing, but he wet it would dad. He climbed many pictures and slide. He has a slow say, "Lar!" as something happy and said, "Don't worry," he said. She began to go for a walk to the puddle. Jack grabbed the ground making yuck saying and began to help again. Jack told her to eat for the water and felt through. One day, Jack remembered him to eat them. He was very enough for deep her for the waves and they helped to find his hands. He wanted to stop up and he had seen his new things. But he learned that
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 3700 | Train Loss 1.4286326169967651 | Validation Loss 1.2415707111358643
# Sampled Text:
# Jack and Jill went to the park. Mary was a better a called Rety. The cozy started to cross the trees and the little knife at the bone. Suddenly, Jack also fur was so small. Jack said, "Thatâ€TMs obsive uniquaries on. I won for birthday," Jack smiled. So, "I of the world, Let's made good birth you bring a bunny more toy. Thisy reaches follow. Then Tink playing, he is a new friend vanor. Jack smiled and scared his mom aso was not navy. The fish were watching anymore. Jack was so happy that
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 3800 | Train Loss 1.3913499116897583 | Validation Loss 1.2383053302764893
# Sampled Text:
# Jack and Jill went to the park with their mom and daddy. Jack heard a loud adventures of them. He picked him up and said, "Can I have to stay dressxes around, "I can balance!" Jould whistle without wewards the nice big red paperes. He told him to was quick and they did it mixing it lost it. At grayy kept walking and she was carried. Lasa was sad and scared. He was very tall, "I hurt you forbone to look at?" She was sad. She and gave it to keep the red down from the lion, and stayed so helpful, more loud understanding. One night,
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 3900 | Train Loss 1.3821191787719727 | Validation Loss 1.2280393838882446
# Sampled Text:
# Jack and Jill went on a phone. He rip never saw a rest of mustast. He went to the tree, more water, enjoys. He helped his tree. His feet was tired out. He asked his grandma looked up, but he was sad for a little girl. The blebroua said no. He said goodbye there to his doctor. Jack asked what he was happily man. Jack was not not too hard named Buudy and a clean. Everyone was scared and duck still slowly. He was done, so he brought the whole alire we can stay, eating. "Can you be dire you build this!" Mia looked so happy when he looked every down
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 4000 | Train Loss 1.3854740858078003 | Validation Loss 1.2261021137237549
# Sampled Text:
# Jack and Jill went to the kitchen. He saw a happi were bigger. He saw a apples. "But now!" agread said. "Cve castle, it's not you. The next time, Jack. We did not explore soting happy. You have to tray breaks. Ha is special. That is it." His mom nodded. She was delighting another hug. He give them two best with his seal. Then he shouted, "Hello, I'm very happy!" One day, Jack as away, said, "Okay, and Little sweet. Dean are just Or. With it" now. He ran back with his mom and the raft her mom
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 4100 | Train Loss 1.390939474105835 | Validation Loss 1.2200069427490234
# Sampled Text:
# Jack and Jill went to look away. Harry was so excited Qoo while they got to the sunshine. Kat. He wanted to the middle of kitchen to big, but he was instead. He wished asked her image a big trees and smiled. They hugged his mom to see Jack for him and make a tree. Jack went for a walk, "Goodse, Jack, ofcrite!" Jack said, Luna took a long wand and said, "I miss too you no, Mom! have to go down that you see!" Cite of them happily. Fred washing for Bob so Katared. He loved to see what stady down the jewel. He wanted to leave, calling
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 4200 | Train Loss 1.3667700290679932 | Validation Loss 1.2127970457077026
# Sampled Text:
# Jack and Jill went to the park. They saw a cookie. Jill and Sam were painting lots of fun. They went to the cat with their pocket. Sam nodded. John, a lot of comb of train and Sam finally went to his mom. "Hey, dad, Sam! Tho, I found a big look." Juck thought the jewel with check and bigger and all day he had an idea. Jake reaknage thought about their cave. He pulled up heading rope and settled. The corriend couldn't find his shoe wings. Sam said, "Why are you my cake,. You have a different things!â€ I
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 4300 | Train Loss 1.3857505321502686 | Validation Loss 1.2081992626190186
# Sampled Text:
# Jack and Jill went to the front and the bunny who saw a big far garden. They had lots of fun, but they heard a sack, so they found some other flowers back. Sue saw Ben and then tasted food up. They put on the sky and truck through the day. After the busy marber, they saw creations. They walked down and strong it up, some mugs. They are calm angry and started to rest off. They slid down and began to find some balutes. Jack was so happy that it try and freeze was very sad. They decided to share the door and be act. They looked up, then a kind work with it
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 4400 | Train Loss 1.3630540370941162 | Validation Loss 1.2044661045074463
# Sampled Text:
# Jack and Jill went to the park when they finally heard a lot ofsticely. After it, Jack wanted to learn it, "Let's go for a walk. He seek's trouble. If you be his rain." She wanted to wait for his seet and said, "Hello, have a ice snake. We can make all more your birthful bamin with me?" But and mom sat down the park. The kid had a strrip of work. It was cool with our animals. Jack didn't make the barrel. Finally, he discovered the hole. He took out to look at help and winted buttoned. It was my others, and Jack
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 4500 | Train Loss 1.342250108718872 | Validation Loss 1.1996283531188965
# Sampled Text:
# Jack and Jill went to the park with their mom. Jack was very excited and said, "What's a green foozor shape if This is Sam! Why did you can play with here." This who lived happily and Jack for a brave whistle. He asked his mom, "Oh no! I love it." Jack was so happy, and Jacks, Jack smiled and he said After tight. He hoped all a hat buse he started to dade. He was stellerstaad and strongs of into time. He tried to try to if they seem if the bush's teach feeling chose what they could do. They got lafnny, so he woke up and like a few m
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 4600 | Train Loss 1.3359992504119873 | Validation Loss 1.1955240964889526
# Sampled Text:
# Jack and Jill went to the other animals. They wanted to did, but he could not fix him. Jack said it was a checket to the crappla can. He started to answer to the store and forget May to go. He clapped and thought for a moment. Iice thing with When he was down the yarn. His goodby was so excited to see what was inside. Jack pulled away and asked him if he could take it. "Can you play a nice car," said Down. Mia! She saw a playful bright looks in the surprise. She did not know how to leave and play out it. Then he taught the sunshine, "Oh no, you split?" "You
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 4700 | Train Loss 1.3532180786132812 | Validation Loss 1.1923514604568481
# Sampled Text:
# Jack and Jill went to to play with lid with others. They had a many new king bee!" They walked with Lily's dad. Jill and Tom looked at it and smiled. They pretend they had off the next day, Jack and Lily's bug away, and she thought it was not proud of himself. She said that Tom sharted them, "Chan I buy it, it is your my journeure." Jack took him to study, and Jack was come back with their phone unlock. One day, Ben, they saw a special car on the cornor's juice. He was so happy and proud of Lily and Lily saw a truck. Her mom said, "I don't worry, Max
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 4800 | Train Loss 1.3655593395233154 | Validation Loss 1.186484932899475
# Sampled Text:
# Jack and Jill went to the park. They saw a fun day with a big bo boy, and some puzzles, feeling since. Every squauzz too. He was very surprised. He wore it enjoyed him a big hug and truck picked its hands in the sky. He felt gentle at the hall, food he could do to make something new and growl and ask for the tree. He ran towards the tree, would always remind it for him. But it looked in calenda. Would lister to make its pockets and holder rockets. He smiled and smiled. The girl was happy to help him. But, he was so bright! about other everyday d
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 4900 | Train Loss 1.3154462575912476 | Validation Loss 1.1832377910614014
# Sampled Text:
# Jack and Jill went to the park. But then, Sue heard a loud card because he was having so pretty. He picked his dad to her grinner, saw something first again. Sue had a pick out that he saw a big apple. "We are very true! With line!" Jack smiled at his scooter. His mom smiled. "Bad, I can play together." She said his brother and hugged him. "Oh no, it's expensive in your adventures," his mum said. She hugged the woman to listen to Tom and put down the hill. Jack let go up and held the mirror. He wanted to come out. He quick
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 5000 | Train Loss 1.3184192180633545 | Validation Loss 1.1784638166427612
# Sampled Text:
# Jack and Jill went to the hot trum soon. They saw a big spruth and reading out! He moved out the key with an aspore job. It was a grateful where he clapped he had never having a playground to water and but Jack started rope. He kept the other sky, two thiss pigson. Suddenly, Jack said, "Good minute?" Jack and Jill used to try it from theirâ€TMs mom, Jack went for a lot of money. Jack's dad was scared but Dum said, "Let's yurt the mystery door, the Ose a hole time!" Jack said, "C
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 5100 | Train Loss 1.3202779293060303 | Validation Loss 1.1773693561553955
# Sampled Text:
# Jack and Jill went to the music. He loved it very competitive in the seal. Everyone was a little boy who loved to make the park! He was so proud of him, an pictures. One day, his family thought. He belonged to a man of adventure! Jack was feeling very sad. He quickly. He thought it was too jump and thanked him mom. He was so little boy. He wanted to help him. He was a little rabbit with. He was still happy. He hugged him and said "Okay, who are not so busy!" Jack said. Jack was so happy. He was so careful nothing the bathrobe. He was really very happy. He ran over to play. He op
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 5200 | Train Loss 1.3118338584899902 | Validation Loss 1.1733145713806152
# Sampled Text:
# Jack and Jill went to the grass. He saw a clubed the slide. He made an iglooh on him and scared the soft was something it was. He smiled and started an cold. Jack saw the sled and dog went fast. The next plant chicken and she went away. Jack's mom smiled and said it was too. He was very soaking it from new. Jack had scared his drop. Mom looked around and saw the sunshine. It was ignorance to be hurt and don't'm ok, but he used to can tell his mother. But Jack wanted to go home with happines. He gave him a big cloud inkeysile and Sared and he blue again. He played at t
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 5300 | Train Loss 1.3132963180541992 | Validation Loss 1.1695997714996338
# Sampled Text:
# Jack and Jill went to the nearby but the geet was reached. Jack loared to have building enough to her of the edge. Jack wanted to run out on the switch. He ran to the garden and Jack thought it would reached it. He enjoyed why she put them in one happened. Jack was scared, he had ever seen slowooking. The That morning home, Jack thought he had a trip. Jill felt such a mistake! It spun to do her children yummy night he had out. He was a brave far away. He quickly flew a feather in a a kite trees and didn't let
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 5400 | Train Loss 1.2983406782150269 | Validation Loss 1.167295217514038
# Sampled Text:
# Jack and Jill went to the rod. They saw a big hat rock in the park. As the log was carrot in the leopard, he saw a shiny black car. He looked up to his mom and sighed. "Let me, Jack, who is different." Jack a flute artion with the black hard when they thought it was time to try it. As they wore the bag, they was fearful where they saw a new puddles. Het he had lots of fun because it made it closer to the same way. Suddenly, Jack saw him how to catch it. He took and swam over to the hidden space. It was a big voice. "N
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 5500 | Train Loss 1.2689409255981445 | Validation Loss 1.1630291938781738
# Sampled Text:
# Jack and Jill went outside to play near the park. He walked outmy on the dater and flew down in the slide. So, Jack ran over to it, and the duck tried towards the big tree together. He heard a loud noise on a feet. Jack finished, he saw some repairs to look for something there. It doesn't do what was not healthy. She wanted to draw his legs, but it was too other and important. It made John's watching his toys and laughed, but then his mommy was notn't stop. They got green the beautiful things happiness, but he thought about it. Jack crashed
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 5600 | Train Loss 1.3233586549758911 | Validation Loss 1.159747838973999
# Sampled Text:
# Jack and Jill went to the louder place. As Lily wanted to comes about it, Jack and his neighbor said kids, "No the lug and I have yourself for you?" Jack said, "Of course! Hannop the persent is the pretty spade for a gue." Jack was so sad and thought of a peace to buy her pretty paper. She hopped around and said, "What memor to the kitchen. He will ask stucks; it's please for you. I am beautiful dragons. But That's wrong understand of people to hear this. Everyone
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 5700 | Train Loss 1.2968319654464722 | Validation Loss 1.1579152345657349
# Sampled Text:
# Jack and Jill went to the park with his new blitten and a smile. As they were finished, Jack saw something stick that always showed people. It was a little quiet love. Jack was very bad! He couldn't understand while they had a funny day. Suddenly, the help came out of the world. Jack then found a magical turtle, and that it barked clisting. Jack gave them for the kids with it. It was a lot of fun day, knowing out her call. He was very smiling. When they got to the lake and toys never called it. Jack," Jill stayed a small bird. His mom said, "In't belong
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 5800 | Train Loss 1.310579538345337 | Validation Loss 1.1554397344589233
# Sampled Text:
# ...
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 31300 | Train Loss 1.1088228225708008 | Validation Loss 0.9896876215934753
# Sampled Text:
# Jack and Jill went to the adventure. They were leaving after lots of vases. One day, Suddenly, Jack was getting dark for a rest of advice. Suddenly, a taxi was bed and big then. It was a small dog. Jack was an violin! Jack wanted to climb the taxi. He ran over to the cave and ran about the stick. He couldn't see the taxi and Jack was very happy. Suddenly, a sad voice complain little heavy prize. Tom felt thoughtful and said that he was the end. He was there. The tasted lots of prize oall tasty toy he
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 31400 | Train Loss 1.1425840854644775 | Validation Loss 0.988874077796936
# Sampled Text:
# Jack and Jill went to the store with Timmy's name. "Wow, look at that hot!" climbed the house and they laughed. "Let's go have fun!" they school. Jack said "No, that was so funny! What did it?" Jack's juice was very excited, so they sneezed with the carrot's room. "Look! Come on my house!" Jack said. "Maybe they can sing too." Jill was excited for him and asked this, "Sure, we can be shiny and pretty. It will get your adventure and it is very long!" Jill was so happy. But Jack only made another nation and they started to cry. J
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 31500 | Train Loss 1.108211874961853 | Validation Loss 0.9885052442550659
# Sampled Text:
# Jack and Jill went outside and saw a big door as the door when they were in the backyard was having so organizing. Maye grabbed lions and spinned hiding track. The doctors let as he talked and held it in the sky. They were still is very impressed, and his friends said goodbye to everything, and the doll was number and excited. The doctor kept going arning and bring good friends, but the door jumped and continued playing, fading around the stage. Jack liked to play with his dolls but much animals. Finally, the doctors were dumbled and shut
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 31600 | Train Loss 1.1151806116104126 | Validation Loss 0.9887263178825378
# Sampled Text:
# Jack and Jill went to the lake and Mom had a beautiful line. Mom was happy. When Mom was going to the smelly pot everything sashed again and was a fire. The end. ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 31700 | Train Loss 1.1167751550674438 | Validation Loss 0.9889527559280396
# Sampled Text:
# Jack and Jill went to school. They showed Tom to the piano, then he wasn't flying. "Mommy, take a nap. I am scary!" Just another sound, and he felt very happy. ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 31800 | Train Loss 1.1123583316802979 | Validation Loss 0.9877744913101196
# Sampled Text:
# Jack and Jill went for a walk. One day, the little boy saw a brown cushion. Jack was feeling very curious. He was so impressed. He held onto it brightly and then got next to them. The cup and Smith was so excited. Jack said he could lift right and down for everyone to help if he could help. He kept closer and just used it to try. It was dark and nice. Jack followed his secret dress away. He thought had to build something glow clean. Jack's mum couldn't find a tall the top back and get his warm flower from that letter reniciting
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 31900 | Train Loss 1.1177854537963867 | Validation Loss 0.9877794981002808
# Sampled Text:
# Jack and Jill went to the park. They saw a big red weird doll and wanted to see what was doing. They were doing the sun and broke and some cool felt like the logs. It was restored! Jill took a hides on the ground and ran outside. Each excitement put it there. It was a new box. It wanted to dirt dum and some cup for another printer. Jill ran to the car and thought Mom would look for it. She put on a water and looked at them and they would go away. Jill was no longer happy. So they planted their king because they were eager to be worried and showed she had to be for not being more. Jill tried to move it
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 32000 | Train Loss 1.11636221408844 | Validation Loss 0.9874178171157837
# Sampled Text:
# Jack and Jill went outside to play. They had a fun day. Mom spotted some pears, a long branch in the park. She was so attached Alice because the room was tired. Jill said hello â€“ It had a tree. But Jill had to wait. She said everyone drove away too, and Jack wanted to work with her. Jill did not forget to bring it. But then, something special happened. Tom and Suddenly, when they got there, something on the ground. It was a red box behind!" Mom pushed them. Mom came by, but he couldnâ€TMt still under a tree. When they arrived at the fire, Jack took started
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 32100 | Train Loss 1.1228413581848145 | Validation Loss 0.9875257611274719
# Sampled Text:
# Jack and Jill went to play with their friends. They liked to play with their toys and run around and squirrels around. One day, Jack and Jill who were so happy. They played with themn't play pink and had fun to block. Jill was so happy he had a big, red ball with his dolls. He put on the tables and running into warm stamps. Jill felt much brave and quietly. Their mom chased the dolls and Todd. She looked at the ball and said, "Let's play with the car. We are spying long and we shared things in your head. You should be selfish and shome. We might can bounce with kids." Jill
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 32200 | Train Loss 1.1290371417999268 | Validation Loss 0.9878581762313843
# Sampled Text:
# Jack and Jill went to the park. They danced and jumped! Holly was very obedient. It was a little girl who lived in a big costume with yummy slides and down and dance. They were so excited to hear the diamond as he rested. Jill remembered what they could have. She was excited and Jill. She learned that it is a surprise with things. It was a lollipop, up and books in forthe playing in his new place. Go matter how they were fommering. But Everyone was scared and wanted to keep the special lesson. So, they spent the kitchen because they got no
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 32300 | Train Loss 1.1303080320358276 | Validation Loss 0.9889434576034546
# Sampled Text:
# Jack and Jill went to bed. They saw a big bee. It was ringing for some mine, and the apple. The apple was so fat. Jill called her - the apple began to fly in the jar. It was so clear. Jill took Jack to the side of them and tried back. Pick was very impressed. Jack said, "I was helping the apple in the backyard. Bick again!" He hopped as fast as he could and began to talk something soft. Jill took all the apples up, just then There the birds? He asked the bird. Jenny and Jill saw that the apple was dark that they were too nice for the ant who found some c
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 32400 | Train Loss 1.1265652179718018 | Validation Loss 0.9881958961486816
# Sampled Text:
# Jack and Jill went to a trip. Everyone was 3 years old openly rolling in the night. Jack was excited. The man watched him up and said: "We can grab your night!" Suddenly, Jack heard a loud noise. He looked around and saw a voice. The old man gave him some bananas and said "Tim. Stop it, I will go to bed." The old man reminded, so he just looked out to shoot of jail in the park. The old man thought about what was going to have. It screamed at them all of the chocolate, and they jumped. Jack smiled and said, "That's a big, in the
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 32500 | Train Loss 1.0891821384429932 | Validation Loss 0.9857986569404602
# Sampled Text:
# Jack and Jill went to a park to read. They smiled and said, "Look, Jack, I'm a person!" Jack said yes. He was excited and they went outside to leave. After the day, his mom and Dad all said, "Let's go go on a walk!" They played a game and the dog moved ready for sashing. Mom asked the dog, a ant came inside and said, "Can we go in the park?" Jack said, and Jack lay into the forest. The two of them come home. I found some people how important it was, and Jack left in what it was. They saw the rabbit from with treading. Mom smiled and said, "That's very
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 32600 | Train Loss 1.102614402770996 | Validation Loss 0.9868053197860718
# Sampled Text:
# Jack and Jill went to the parking home. As they finished sunglowly, they saw something on the ground. It was a scary lady! Jack and his friend opened it, and Sam couldn't show each all the special ladder. When they got there, something special! It was a lawn! It was a special bed of the lights! But the father was too much fun and all lived happily as they grabbed its sharp pieces. Millie said, "Thank you, L bird! I'm so polite!" Jack nodded with joy on his cardboard and he tried to snack the bed. What happened?" Luc
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 32700 | Train Loss 1.1324423551559448 | Validation Loss 0.9872475862503052
# Sampled Text:
# Jack and Jill went outside with their swings. They saw a big pile of lamp and turned out. It was bigger, butterflys. Tom was scared. He had teach his noise in the living room. His mom and dad said yes. They rescued their things that they hit the dog. The dog sat down and grabbed Tom's arm to forget. It was his dog hopping at his owner. Jill and Tom decided to dark to everyone to make outside. They walked laughing and had fun. They had a lot of fun. Jack was happy playing and that Tom had no little time playing. Afterwards, Jill would have a lot of fun. ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 32800 | Train Loss 1.1054376363754272 | Validation Loss 0.9875760078430176
# Sampled Text:
# Jack and Jill went for a walk in the park. They saw a ground and ditten spoke. The restaurant sounds that seems lots of very high. Mutse wanted to get it back to the slide. Jack felt like a big, radish and scary outside in the light. There was a mailman of tea cute. She lifted it to a place to take. She took the warm day, pandament and watered it back to the rules. Matty went asleep, both glassed down. He liked catching a slide and the big discover. He kept holding the pilot slowly. J
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 32900 | Train Loss 1.1317813396453857 | Validation Loss 0.986797034740448
# Sampled Text:
# Jack and Jill went to the window. They saw all of kings, books, pids and skills. They had long books and her family. They peeked and had lots of fun. "Can I play with my doctors?" Jill said. She said, "No, Tom!," said them to Mom. Jill and Jen said to Mr. The dinosaur's dogs. They put on their head and watered on the wall. They led the toy face, swimming off with her. They wore the black pocket again, but the rock started to grow and put their toys on their desk. "Please, it's time to eat!" Tom shouted, "I fit your toy cat w
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 33000 | Train Loss 1.1129190921783447 | Validation Loss 0.9871132969856262
# Sampled Text:
# Jack and Jill went to the park and got tired. They saw a big, yellow pigeon on the bench. It was very surprised. The next day, the reverember started to poke the water. It saw something yummy. It was an oun at that he said "No! What did you do?" Jill the piged into the park. They saw a shiny day and a big tym. It was stuck in the distance. It was a little butter on the ground. Jill found them all all day long. He guessed the road free on the slide and laughed again! The old man was sad because they knew the princess was lost.. Jill loved it! He
# ================================================================================
# ================================================================================
# Epoch 0 | Batch 33100 | Train Loss 1.1247453689575195 | Validation Loss 0.9869159460067749
# Sampled Text:
# Jack and Jill went to the mirror and walked as faces in the woods. They saw a pot of microphone on the mirrors. It was very big and cool. Jill smiled. It was not glad to curl in the bush and swing over and run to the pitch with paper! Jill said to him, "Wow I want to give you a microscope he can." Jack was so happy and ran to playing with the mask. When Jack surrenders they crawled inside the yard. As they were only three years, it was time to pick out. She was ready to go home and blew it at day as a player for the nice food." She
# ================================================================================

# %%
torch.save(model.state_dict(), "babby-lm270k-TinyStories.pth")
